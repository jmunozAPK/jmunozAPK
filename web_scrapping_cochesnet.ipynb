# %%
pip install beautifulsoup4 requests
# Out:
# ...
#   Using cached requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# ...
#   Using cached idna-3.7-py3-none-any.whl.metadata (9.9 kB)
# ...
#   Using cached urllib3-2.2.2-py3-none-any.whl.metadata (6.4 kB)
# ...
#   Using cached certifi-2024.6.2-py3-none-any.whl.metadata (2.2 kB)
# ...
#    ---------------------------------------- 0.0/147.9 kB ? eta -:--:--
#    ---------- ---------------------------- 41.0/147.9 kB 991.0 kB/s eta 0:00:01
#    ---------------------------------------- 147.9/147.9 kB 2.2 MB/s eta 0:00:00
# Using cached requests-2.32.3-py3-none-any.whl (64 kB)
# Using cached certifi-2024.6.2-py3-none-any.whl (164 kB)
# Using cached idna-3.7-py3-none-any.whl (66 kB)
# ...
# Using cached urllib3-2.2.2-py3-none-any.whl (121 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# <span style="color:yellow">*Web Scraping*</span> <span style="color:orange">vehículo renting de forma individual</span>.

# %%
from bs4 import BeautifulSoup

# HTML proporcionado
html = '''
<div class="sui-AtomCard-info">
    <a href="/renting/seat/ibiza/10_tsi_70kw_95cv_reference_xl-gasolina-2024-57091107-vsre" class="mt-CardBasic-titleLink" title="SEAT Ibiza 1.0 TSI 70kW 95CV Reference XL 5p." target="_self">
        <div class="mt-CardAdPrice">
            <div class="mt-CardAdPrice-subscription mt-CardAdPrice-subscription--fullwidth">
                <div class="mt-CardAdPrice-priceIndicator is-clickable">
                    <div class="mt-CardAdPrice-priceIndicatorTitle">
                        <span class="mt-CardAdPrice-cashLabel mt-CardAdPrice-cashLabel--noWrap">Buen precio</span>
                    </div>
                    <div class="mt-CardAdPrice-priceIndicatorContainer mt-CardAdPrice-priceIndicatorContainer--small">
                        <span class="mt-CardAdPrice-priceIndicatorContainerItem mt-CardAdPrice-priceIndicatorContainerItem--green"></span>
                        <span class="mt-CardAdPrice-priceIndicatorContainerItem mt-CardAdPrice-priceIndicatorContainerItem--green"></span>
                        <span class="mt-CardAdPrice-priceIndicatorContainerItem mt-CardAdPrice-priceIndicatorContainerItem--green"></span>
                        <span class="mt-CardAdPrice-priceIndicatorContainerItem mt-CardAdPrice-priceIndicatorContainerItem--green"></span>
                        <span class="mt-CardAdPrice-priceIndicatorContainerItem mt-CardAdPrice-priceIndicatorContainerItem--default"></span>
                    </div>
                </div>
                <div class="mt-CardAdPrice-subscriptionAmount">
                    <div class="mt-TitleBasic-titleWrapper mt-TitleBasic-titleWrapper--currentColor mt-TitleBasic-titleWrapper--left">
                        <h3 class="mt-TitleBasic-title mt-TitleBasic-title--s mt-TitleBasic-title--currentColor">253&nbsp;€</h3>
                    </div>
                    <span class="mt-CardAdPrice-subscriptionAmountPerMonth">/mes*</span>
                </div>
                <div class="mt-CardAdPrice-subscriptionLabel">
                    <span class="mt-CardAdPrice-subscriptionLabel--highlight">IVA incluido</span>
                </div>
            </div>
        </div>
        <h2 class="mt-CardBasic-title mt-CardAd-title--oneLine" data-testid="card-ad-title">SEAT Ibiza 1.0 TSI 70kW 95CV Reference XL 5p.</h2>
        <ul class="mt-CardAd-attr">
            <li class="mt-CardAd-attrItem">Gasolina</li>
            <li class="mt-CardAd-attrItem">2023</li>
            <li class="mt-CardAd-attrItem">Manual</li>
        </ul>
        <ul class="mt-CardAd-tags">
            <div class="sui-AtomBadge sui-AtomBadge-size-medium sui-AtomBadge-type-gray sui-AtomBadge-design-soft">
                <span class="sui-AtomBadge-icon-text" title="Nuevo">Nuevo</span>
            </div>
        </ul>
    </a>
</div>
'''

# Parsear el HTML con BeautifulSoup
soup = BeautifulSoup(html, 'html.parser')

# Extraer el título del vehículo
title_element = soup.find('h2', class_='mt-CardBasic-title')
vehicle_title = title_element.text.strip() if title_element else "No encontrado"

# Extraer atributos (combustible, año, transmisión)
attr_elements = soup.find_all('li', class_='mt-CardAd-attrItem')
attributes = [attr.text.strip() for attr in attr_elements]

# Extraer si es nuevo
new_element = soup.find('span', class_='sui-AtomBadge-icon-text', title='Nuevo')
is_new = "Sí" if new_element else "No"

# Extraer el precio mensual
price_element = soup.find('h3', class_='mt-TitleBasic-title')
monthly_price = price_element.text.strip() if price_element else "No encontrado"

# Imprimir los resultados
print("Título del vehículo:", vehicle_title)
print("Atributos:", attributes)
print("Nuevo:", is_new)
print("Precio mensual:", monthly_price)
# Out:
# Título del vehículo: SEAT Ibiza 1.0 TSI 70kW 95CV Reference XL 5p.
# Atributos: ['Gasolina', '2023', 'Manual']
# Nuevo: Sí
# Precio mensual: 253 €

# %% [markdown]
# <span style="color:yellow">*Web Scraping*</span> <span style="color:orange">por página (sección renting)</span>.

# %%
#EXTRACCIÓN PERFECTA POR PÁGINA

from bs4 import BeautifulSoup

# Supongamos que tienes el HTML de una página completa que contiene varios vehículos y anuncios
html = '''
<div class="mt-ListAds">
    <div data-ad-id="57091107">
        <div class="mt-AnimationFadeOut mt-ListAds-item mt-CardAd mt-CardBasic">
            <div class="sui-AtomCard sui-AtomCard--responsive" role="button">
                <div class="sui-AtomCard-media">
                    <div class="mt-CardAd-mediaContainer"><a class="mt-CardAd-media " href="/renting/seat/ibiza/10_tsi_70kw_95cv_reference_xl-gasolina-2024-57091107-vsre" target="_self" title="SEAT Ibiza 1.0 TSI 70kW 95CV Reference XL 5p.">
                            <div class="sui-AtomImage is-loaded">
                                <figure class="sui-AtomImage-figure">
                                    <picture><img alt="SEAT Ibiza 1.0 TSI 70kW 95CV Reference XL 5p." class="mt-CardAd-mediaImage" decoding="auto" fetchpriority="high" loading="eager" height="189" src="https://a.ccdn.es/cnet/2024/02/08/57091107/1898002608_g.jpg/252x189cut/" width="252" title="SEAT Ibiza 1.0 TSI 70kW 95CV Reference XL 5p."></picture>
                                </figure>
                            </div>
                        </a></div>
                </div>
                <div class="sui-AtomCard-info"><a href="/renting/seat/ibiza/10_tsi_70kw_95cv_reference_xl-gasolina-2024-57091107-vsre" class="mt-CardBasic-titleLink" title="SEAT Ibiza 1.0 TSI 70kW 95CV Reference XL 5p." target="_self">
                        <div class="mt-CardAdPrice">
                            <div class="mt-CardAdPrice-subscription mt-CardAdPrice-subscription--fullwidth">
                                <div class="mt-CardAdPrice-priceIndicator is-clickable">
                                    <div class="mt-CardAdPrice-priceIndicatorTitle"><span class="mt-CardAdPrice-cashLabel mt-CardAdPrice-cashLabel--noWrap">Buen precio</span></div>
                                    <div class="mt-CardAdPrice-priceIndicatorContainer mt-CardAdPrice-priceIndicatorContainer--small"><span class="mt-CardAdPrice-priceIndicatorContainerItem mt-CardAdPrice-priceIndicatorContainerItem--green"></span><span class="mt-CardAdPrice-priceIndicatorContainerItem mt-CardAdPrice-priceIndicatorContainerItem--green"></span><span class="mt-CardAdPrice-priceIndicatorContainerItem mt-CardAdPrice-priceIndicatorContainerItem--green"></span><span class="mt-CardAdPrice-priceIndicatorContainerItem mt-CardAdPrice-priceIndicatorContainerItem--green"></span><span class="mt-CardAdPrice-priceIndicatorContainerItem mt-CardAdPrice-priceIndicatorContainerItem--default"></span></div>
                                </div>
                                <div class="mt-CardAdPrice-subscriptionAmount">
                                    <div class="mt-TitleBasic-titleWrapper mt-TitleBasic-titleWrapper--currentColor mt-TitleBasic-titleWrapper--left">
                                        <h3 class="mt-TitleBasic-title mt-TitleBasic-title--s mt-TitleBasic-title--currentColor">253&nbsp;€</h3>
                                    </div><span class="mt-CardAdPrice-subscriptionAmountPerMonth">/mes*</span>
                                </div>
                                <div class="mt-CardAdPrice-subscriptionLabel"><span class="mt-CardAdPrice-subscriptionLabel--highlight">IVA incluido</span></div>
                            </div>
                        </div>
                        <h2 class="mt-CardBasic-title mt-CardAd-title--oneLine" data-testid="card-ad-title">SEAT Ibiza 1.0 TSI 70kW 95CV Reference XL 5p.</h2>
                        <ul class="mt-CardAd-attr">
                            <li class="mt-CardAd-attrItem">Gasolina</li>
                            <li class="mt-CardAd-attrItem">2023</li>
                            <li class="mt-CardAd-attrItem">Manual</li>
                        </ul>
                        <ul class="mt-CardAd-tags">
                            <div class="sui-AtomBadge sui-AtomBadge-size-medium sui-AtomBadge-type-gray sui-AtomBadge-design-soft"><span class="sui-AtomBadge-icon-text" title="Nuevo">Nuevo</span></div>
                        </ul>
                    </a></div>
            </div>
            <div class="mt-CardAd-fav">
                <div class="mt-CardAd-favIcon"><span class="sui-AtomIcon sui-AtomIcon--medium sui-AtomIcon--currentColor"><span><svg viewBox="0 0 24 24" xmlns="http://www.w3.org/2000/svg">
                                <path d="M6.607 3.057c1.93-.279 4.02.469 5.393 2.171 1.373-1.702 3.462-2.45 5.393-2.171a5.17 5.17 0 0 1 3.248 1.79C21.501 5.872 22 7.27 22 8.972c0 3.474-2.56 6.49-4.835 8.516a29.628 29.628 0 0 1-4.678 3.386 1 1 0 0 1-.974 0c-.14-.08-.279-.162-.417-.245a29.633 29.633 0 0 1-4.261-3.14C4.56 15.461 2 12.445 2 8.971c0-1.703.499-3.1 1.359-4.125a5.17 5.17 0 0 1 3.248-1.79Z"></path>
                            </svg></span></span></div>
            </div>
            <div class="mt-CardAd-footer">
                <div class="mt-CardAd-footerFinancingInfoContainer">* Permanencia: 60 meses · Kilómetros incluidos: 10.000 /año · También disponible: 48 meses</div>
            </div>
        </div>
    </div>
    <div data-ad-id="58098037">
        <div class="mt-AnimationFadeOut mt-ListAds-item mt-CardAd mt-CardBasic">
            <div class="sui-AtomCard sui-AtomCard--responsive" role="button">
                <div class="sui-AtomCard-media">
                    <div class="mt-CardAd-mediaContainer"><a class="mt-CardAd-media " href="/renting/renault/clio/business_sce_49_kw_67cv-gasolina-2021-58098037-vsre" target="_self" title="RENAULT Clio Business SCe 49 kW 67CV 5p.">
                            <div class="sui-AtomImage is-loaded">
                                <figure class="sui-AtomImage-figure">
                                    <picture><img alt="RENAULT Clio Business SCe 49 kW 67CV 5p." class="mt-CardAd-mediaImage" decoding="auto" fetchpriority="high" loading="eager" height="189" src="https://a.ccdn.es/cnet/2024/06/18/58098037/1926852955_g.jpg/252x189cut/" width="252" title="RENAULT Clio Business SCe 49 kW 67CV 5p."></picture>
                                </figure>
                            </div>
                        </a></div>
                </div>
                <div class="sui-AtomCard-info"><a href="/renting/renault/clio/business_sce_49_kw_67cv-gasolina-2021-58098037-vsre" class="mt-CardBasic-titleLink" title="RENAULT Clio Business SCe 49 kW 67CV 5p." target="_self">
                        <div class="mt-CardAdPrice">
                            <div class="mt-CardAdPrice-subscription mt-CardAdPrice-subscription--fullwidth"><span class="mt-CardAdPrice-subscriptionLabel">Cuota desde</span>
                                <div class="mt-CardAdPrice-subscriptionAmount">
                                    <div class="mt-TitleBasic-titleWrapper mt-TitleBasic-titleWrapper--currentColor mt-TitleBasic-titleWrapper--left">
                                        <h3 class="mt-TitleBasic-title mt-TitleBasic-title--s mt-TitleBasic-title--currentColor">295&nbsp;€</h3>
                                    </div><span class="mt-CardAdPrice-subscriptionAmountPerMonth">/mes*</span>
                                </div>
                                <div class="mt-CardAdPrice-subscriptionLabel"><span class="mt-CardAdPrice-subscriptionLabel--highlight">IVA incluido</span></div>
                            </div>
                        </div>
                        <h2 class="mt-CardBasic-title mt-CardAd-title--oneLine" data-testid="card-ad-title">RENAULT Clio Business SCe 49 kW 67CV 5p.</h2>
                        <ul class="mt-CardAd-attr">
                            <li class="mt-CardAd-attrItem">Gasolina</li>
                            <li class="mt-CardAd-attrItem">2021</li>
                            <li class="mt-CardAd-attrItem">Manual</li>
                        </ul>
                        <ul class="mt-CardAd-tags">
                            <div class="sui-AtomBadge sui-AtomBadge-size-medium sui-AtomBadge-type-gray sui-AtomBadge-design-soft"><span class="sui-AtomBadge-icon-text" title="Segunda mano">Segunda mano</span></div>
                        </ul>
                    </a></div>
            </div>
            <div class="mt-CardAd-fav">
                <div class="mt-CardAd-favIcon"><span class="sui-AtomIcon sui-AtomIcon--medium sui-AtomIcon--currentColor"><span><svg viewBox="0 0 24 24" xmlns="http://www.w3.org/2000/svg">
                                <path d="M6.607 3.057c1.93-.279 4.02.469 5.393 2.171 1.373-1.702 3.462-2.45 5.393-2.171a5.17 5.17 0 0 1 3.248 1.79C21.501 5.872 22 7.27 22 8.972c0 3.474-2.56 6.49-4.835 8.516a29.628 29.628 0 0 1-4.678 3.386 1 1 0 0 1-.974 0c-.14-.08-.279-.162-.417-.245a29.633 29.633 0 0 1-4.261-3.14C4.56 15.461 2 12.445 2 8.971c0-1.703.499-3.1 1.359-4.125a5.17 5.17 0 0 1 3.248-1.79Z"></path>
                            </svg></span></span></div>
            </div>
            <div class="mt-CardAd-footer">
                <div class="mt-CardAd-footerFinancingInfoContainer">* Permanencia: 12 meses · Kilómetros incluidos: 10.000 /año</div>
            </div>
        </div>
    </div>
    <div data-ad-id="58154707">
        <div class="mt-AnimationFadeOut mt-ListAds-item mt-CardAd mt-CardBasic">
            <div class="sui-AtomCard sui-AtomCard--responsive" role="button">
                <div class="sui-AtomCard-media">
                    <div class="mt-CardAd-mediaContainer"><a class="mt-CardAd-media " href="/renting/renault/clio/business_sce_49_kw_67cv-gasolina-2021-58154707-vsre" target="_self" title="RENAULT Clio Business SCe 49 kW 67CV 5p.">
                            <div class="sui-AtomImage is-loaded">
                                <figure class="sui-AtomImage-figure">
                                    <picture><img alt="RENAULT Clio Business SCe 49 kW 67CV 5p." class="mt-CardAd-mediaImage" decoding="auto" fetchpriority="auto" loading="eager" height="189" src="https://a.ccdn.es/cnet/2024/06/26/58154707/1929252236_g.jpg/252x189cut/" width="252" title="RENAULT Clio Business SCe 49 kW 67CV 5p."></picture>
                                </figure>
                            </div>
                        </a></div>
                </div>
                <div class="sui-AtomCard-info"><a href="/renting/renault/clio/business_sce_49_kw_67cv-gasolina-2021-58154707-vsre" class="mt-CardBasic-titleLink" title="RENAULT Clio Business SCe 49 kW 67CV 5p." target="_self">
                        <div class="mt-CardAdPrice">
                            <div class="mt-CardAdPrice-subscription mt-CardAdPrice-subscription--fullwidth"><span class="mt-CardAdPrice-subscriptionLabel">Cuota desde</span>
                                <div class="mt-CardAdPrice-subscriptionAmount">
                                    <div class="mt-TitleBasic-titleWrapper mt-TitleBasic-titleWrapper--currentColor mt-TitleBasic-titleWrapper--left">
                                        <h3 class="mt-TitleBasic-title mt-TitleBasic-title--s mt-TitleBasic-title--currentColor">295&nbsp;€</h3>
                                    </div><span class="mt-CardAdPrice-subscriptionAmountPerMonth">/mes*</span>
                                </div>
                                <div class="mt-CardAdPrice-subscriptionLabel"><span class="mt-CardAdPrice-subscriptionLabel--highlight">IVA incluido</span></div>
                            </div>
                        </div>
                        <h2 class="mt-CardBasic-title mt-CardAd-title--oneLine" data-testid="card-ad-title">RENAULT Clio Business SCe 49 kW 67CV 5p.</h2>
                        <ul class="mt-CardAd-attr">
                            <li class="mt-CardAd-attrItem">Gasolina</li>
                            <li class="mt-CardAd-attrItem">2021</li>
                            <li class="mt-CardAd-attrItem">Manual</li>
                        </ul>
                        <ul class="mt-CardAd-tags">
                            <div class="sui-AtomBadge sui-AtomBadge-size-medium sui-AtomBadge-type-gray sui-AtomBadge-design-soft"><span class="sui-AtomBadge-icon-text" title="Segunda mano">Segunda mano</span></div>
                        </ul>
                    </a></div>
            </div>
            <div class="mt-CardAd-fav">
                <div class="mt-CardAd-favIcon"><span class="sui-AtomIcon sui-AtomIcon--medium sui-AtomIcon--currentColor"><span><svg viewBox="0 0 24 24" xmlns="http://www.w3.org/2000/svg">
                                <path d="M6.607 3.057c1.93-.279 4.02.469 5.393 2.171 1.373-1.702 3.462-2.45 5.393-2.171a5.17 5.17 0 0 1 3.248 1.79C21.501 5.872 22 7.27 22 8.972c0 3.474-2.56 6.49-4.835 8.516a29.628 29.628 0 0 1-4.678 3.386 1 1 0 0 1-.974 0c-.14-.08-.279-.162-.417-.245a29.633 29.633 0 0 1-4.261-3.14C4.56 15.461 2 12.445 2 8.971c0-1.703.499-3.1 1.359-4.125a5.17 5.17 0 0 1 3.248-1.79Z"></path>
                            </svg></span></span></div>
            </div>
            <div class="mt-CardAd-footer">
                <div class="mt-CardAd-footerFinancingInfoContainer">* Permanencia: 12 meses · Kilómetros incluidos: 10.000 /año</div>
            </div>
        </div>
    </div>
    <div data-ad-id="54749006">
        <div class="mt-AnimationFadeOut mt-ListAds-item mt-CardAd mt-CardBasic">
            <div class="sui-AtomCard sui-AtomCard--responsive" role="button">
                <div class="sui-AtomCard-media">
                    <div class="mt-CardAd-mediaContainer"><a class="mt-CardAd-media " href="/renting/peugeot/208/puretech_55kw_75cv_active_pack-gasolina-2023-54749006-vsre" target="_self" title="PEUGEOT 208 Active Puretech 100 5p.">
                            <div class="sui-AtomImage is-loaded">
                                <figure class="sui-AtomImage-figure">
                                    <picture><img alt="PEUGEOT 208 Active Puretech 100 5p." class="mt-CardAd-mediaImage" decoding="auto" fetchpriority="auto" loading="eager" height="189" src="https://a.ccdn.es/cnet/2023/03/30/54749006/668422524_g.jpg/252x189cut/" width="252" title="PEUGEOT 208 Active Puretech 100 5p."></picture>
                                </figure>
                            </div>
                        </a></div>
                </div>
                <div class="sui-AtomCard-info"><a href="/renting/peugeot/208/puretech_55kw_75cv_active_pack-gasolina-2023-54749006-vsre" class="mt-CardBasic-titleLink" title="PEUGEOT 208 Active Puretech 100 5p." target="_self">
                        <div class="mt-CardAdPrice">
                            <div class="mt-CardAdPrice-subscription mt-CardAdPrice-subscription--fullwidth">
                                <div class="mt-CardAdPrice-priceIndicator is-clickable">
                                    <div class="mt-CardAdPrice-priceIndicatorTitle"><span class="mt-CardAdPrice-cashLabel mt-CardAdPrice-cashLabel--noWrap">Buen precio</span></div>
                                    <div class="mt-CardAdPrice-priceIndicatorContainer mt-CardAdPrice-priceIndicatorContainer--small"><span class="mt-CardAdPrice-priceIndicatorContainerItem mt-CardAdPrice-priceIndicatorContainerItem--green"></span><span class="mt-CardAdPrice-priceIndicatorContainerItem mt-CardAdPrice-priceIndicatorContainerItem--green"></span><span class="mt-CardAdPrice-priceIndicatorContainerItem mt-CardAdPrice-priceIndicatorContainerItem--green"></span><span class="mt-CardAdPrice-priceIndicatorContainerItem mt-CardAdPrice-priceIndicatorContainerItem--green"></span><span class="mt-CardAdPrice-priceIndicatorContainerItem mt-CardAdPrice-priceIndicatorContainerItem--default"></span></div>
                                </div>
                                <div class="mt-CardAdPrice-subscriptionAmount">
                                    <div class="mt-TitleBasic-titleWrapper mt-TitleBasic-titleWrapper--currentColor mt-TitleBasic-titleWrapper--left">
                                        <h3 class="mt-TitleBasic-title mt-TitleBasic-title--s mt-TitleBasic-title--currentColor">321&nbsp;€</h3>
                                    </div><span class="mt-CardAdPrice-subscriptionAmountPerMonth">/mes*</span>
                                </div>
                                <div class="mt-CardAdPrice-subscriptionLabel"><span class="mt-CardAdPrice-subscriptionLabel--highlight">IVA incluido</span></div>
                            </div>
                        </div>
                        <h2 class="mt-CardBasic-title mt-CardAd-title--oneLine" data-testid="card-ad-title">PEUGEOT 208 Active Puretech 100 5p.</h2>
                        <ul class="mt-CardAd-attr">
                            <li class="mt-CardAd-attrItem">Gasolina</li>
                            <li class="mt-CardAd-attrItem">2023</li>
                            <li class="mt-CardAd-attrItem">Manual</li>
                        </ul>
                        <ul class="mt-CardAd-tags">
                            <div class="sui-AtomBadge sui-AtomBadge-size-medium sui-AtomBadge-type-gray sui-AtomBadge-design-soft"><span class="sui-AtomBadge-icon-text" title="Nuevo">Nuevo</span></div>
                        </ul>
                    </a></div>
            </div>
            <div class="mt-CardAd-fav">
                <div class="mt-CardAd-favIcon"><span class="sui-AtomIcon sui-AtomIcon--medium sui-AtomIcon--currentColor"><span><svg viewBox="0 0 24 24" xmlns="http://www.w3.org/2000/svg">
                                <path d="M6.607 3.057c1.93-.279 4.02.469 5.393 2.171 1.373-1.702 3.462-2.45 5.393-2.171a5.17 5.17 0 0 1 3.248 1.79C21.501 5.872 22 7.27 22 8.972c0 3.474-2.56 6.49-4.835 8.516a29.628 29.628 0 0 1-4.678 3.386 1 1 0 0 1-.974 0c-.14-.08-.279-.162-.417-.245a29.633 29.633 0 0 1-4.261-3.14C4.56 15.461 2 12.445 2 8.971c0-1.703.499-3.1 1.359-4.125a5.17 5.17 0 0 1 3.248-1.79Z"></path>
                            </svg></span></span></div>
            </div>
            <div class="mt-CardAd-footer">
                <div class="mt-CardAd-footerFinancingInfoContainer">* Permanencia: 60 meses · Kilómetros incluidos: 10.000 /año · También disponible: 36 y 48 meses</div>
            </div>
        </div>
    </div>
    <div data-ad-id="55411921">
        <div class="mt-AnimationFadeOut mt-ListAds-item mt-CardAd mt-CardBasic">
            <div class="sui-AtomCard sui-AtomCard--responsive" role="button">
                <div class="sui-AtomCard-media">
                    <div class="mt-CardAd-mediaContainer"><a class="mt-CardAd-media " href="/renting/bmw/serie_1/116d-diesel-2023-55411921-vsre" target="_self" title="BMW Serie 1 116d 5p.">
                            <div class="sui-AtomImage is-loaded">
                                <figure class="sui-AtomImage-figure">
                                    <picture><img alt="BMW Serie 1 116d 5p." class="mt-CardAd-mediaImage" decoding="auto" fetchpriority="auto" loading="eager" height="189" src="https://a.ccdn.es/cnet/2023/06/21/55411921/701538084_g.jpg/252x189cut/" width="252" title="BMW Serie 1 116d 5p."></picture>
                                </figure>
                            </div>
                        </a></div>
                </div>
                <div class="sui-AtomCard-info"><a href="/renting/bmw/serie_1/116d-diesel-2023-55411921-vsre" class="mt-CardBasic-titleLink" title="BMW Serie 1 116d 5p." target="_self">
                        <div class="mt-CardAdPrice">
                            <div class="mt-CardAdPrice-subscription mt-CardAdPrice-subscription--fullwidth">
                                <div class="mt-CardAdPrice-priceIndicator is-clickable">
                                    <div class="mt-CardAdPrice-priceIndicatorTitle"><span class="mt-CardAdPrice-cashLabel mt-CardAdPrice-cashLabel--noWrap">Super precio</span></div>
                                    <div class="mt-CardAdPrice-priceIndicatorContainer mt-CardAdPrice-priceIndicatorContainer--small"><span class="mt-CardAdPrice-priceIndicatorContainerItem mt-CardAdPrice-priceIndicatorContainerItem--green"></span><span class="mt-CardAdPrice-priceIndicatorContainerItem mt-CardAdPrice-priceIndicatorContainerItem--green"></span><span class="mt-CardAdPrice-priceIndicatorContainerItem mt-CardAdPrice-priceIndicatorContainerItem--green"></span><span class="mt-CardAdPrice-priceIndicatorContainerItem mt-CardAdPrice-priceIndicatorContainerItem--green"></span><span class="mt-CardAdPrice-priceIndicatorContainerItem mt-CardAdPrice-priceIndicatorContainerItem--green"></span></div>
                                </div>
                                <div class="mt-CardAdPrice-subscriptionAmount">
                                    <div class="mt-TitleBasic-titleWrapper mt-TitleBasic-titleWrapper--currentColor mt-TitleBasic-titleWrapper--left">
                                        <h3 class="mt-TitleBasic-title mt-TitleBasic-title--s mt-TitleBasic-title--currentColor">399&nbsp;€</h3>
                                    </div><span class="mt-CardAdPrice-subscriptionAmountPerMonth">/mes*</span>
                                </div>
                                <div class="mt-CardAdPrice-subscriptionLabel"><span class="mt-CardAdPrice-subscriptionLabel--highlight">IVA incluido</span></div>
                            </div>
                        </div>
                        <h2 class="mt-CardBasic-title mt-CardAd-title--oneLine" data-testid="card-ad-title">BMW Serie 1 116d 5p.</h2>
                        <ul class="mt-CardAd-attr">
                            <li class="mt-CardAd-attrItem">Diesel</li>
                            <li class="mt-CardAd-attrItem">2023</li>
                            <li class="mt-CardAd-attrItem">Manual</li>
                        </ul>
                        <ul class="mt-CardAd-tags">
                            <div class="sui-AtomBadge sui-AtomBadge-size-medium sui-AtomBadge-type-gray sui-AtomBadge-design-soft"><span class="sui-AtomBadge-icon-text" title="Nuevo">Nuevo</span></div>
                        </ul>
                    </a></div>
            </div>
            <div class="mt-CardAd-fav">
                <div class="mt-CardAd-favIcon"><span class="sui-AtomIcon sui-AtomIcon--medium sui-AtomIcon--currentColor"><span><svg viewBox="0 0 24 24" xmlns="http://www.w3.org/2000/svg">
                                <path d="M6.607 3.057c1.93-.279 4.02.469 5.393 2.171 1.373-1.702 3.462-2.45 5.393-2.171a5.17 5.17 0 0 1 3.248 1.79C21.501 5.872 22 7.27 22 8.972c0 3.474-2.56 6.49-4.835 8.516a29.628 29.628 0 0 1-4.678 3.386 1 1 0 0 1-.974 0c-.14-.08-.279-.162-.417-.245a29.633 29.633 0 0 1-4.261-3.14C4.56 15.461 2 12.445 2 8.971c0-1.703.499-3.1 1.359-4.125a5.17 5.17 0 0 1 3.248-1.79Z"></path>
                            </svg></span></span></div>
            </div>
            <div class="mt-CardAd-footer">
                <div class="mt-CardAd-footerFinancingInfoContainer">* Permanencia: 60 meses · Kilómetros incluidos: 10.000 /año · También disponible: 36 y 48 meses</div>
            </div>
        </div>
    </div>
    <div data-ad-id="58147860">
        <div class="mt-AnimationFadeOut mt-ListAds-item mt-CardAd mt-CardBasic">
            <div class="sui-AtomCard sui-AtomCard--responsive" role="button">
                <div class="sui-AtomCard-media">
                    <div class="mt-CardAd-mediaContainer"><a class="mt-CardAd-media " href="/renting/renault/clio/evolution_dci_100_74kw-diesel-2023-58147860-vsre" target="_self" title="RENAULT Clio Evolution dCi 100 74kw 5p.">
                            <div class="sui-AtomImage is-loaded">
                                <figure class="sui-AtomImage-figure">
                                    <picture><img alt="RENAULT Clio Evolution dCi 100 74kw 5p." class="mt-CardAd-mediaImage" decoding="auto" fetchpriority="auto" loading="eager" height="189" src="https://a.ccdn.es/cnet/2024/06/25/58147860/1928894597_g.jpg/252x189cut/" width="252" title="RENAULT Clio Evolution dCi 100 74kw 5p."></picture>
                                </figure>
                            </div>
                        </a></div>
                </div>
                <div class="sui-AtomCard-info"><a href="/renting/renault/clio/evolution_dci_100_74kw-diesel-2023-58147860-vsre" class="mt-CardBasic-titleLink" title="RENAULT Clio Evolution dCi 100 74kw 5p." target="_self">
                        <div class="mt-CardAdPrice">
                            <div class="mt-CardAdPrice-subscription mt-CardAdPrice-subscription--fullwidth">
                                <div class="mt-CardAdPrice-priceIndicator is-clickable">
                                    <div class="mt-CardAdPrice-priceIndicatorTitle"><span class="mt-CardAdPrice-cashLabel mt-CardAdPrice-cashLabel--noWrap">Buen precio</span></div>
                                    <div class="mt-CardAdPrice-priceIndicatorContainer mt-CardAdPrice-priceIndicatorContainer--small"><span class="mt-CardAdPrice-priceIndicatorContainerItem mt-CardAdPrice-priceIndicatorContainerItem--green"></span><span class="mt-CardAdPrice-priceIndicatorContainerItem mt-CardAdPrice-priceIndicatorContainerItem--green"></span><span class="mt-CardAdPrice-priceIndicatorContainerItem mt-CardAdPrice-priceIndicatorContainerItem--green"></span><span class="mt-CardAdPrice-priceIndicatorContainerItem mt-CardAdPrice-priceIndicatorContainerItem--green"></span><span class="mt-CardAdPrice-priceIndicatorContainerItem mt-CardAdPrice-priceIndicatorContainerItem--default"></span></div>
                                </div>
                                <div class="mt-CardAdPrice-subscriptionAmount">
                                    <div class="mt-TitleBasic-titleWrapper mt-TitleBasic-titleWrapper--currentColor mt-TitleBasic-titleWrapper--left">
                                        <h3 class="mt-TitleBasic-title mt-TitleBasic-title--s mt-TitleBasic-title--currentColor">344&nbsp;€</h3>
                                    </div><span class="mt-CardAdPrice-subscriptionAmountPerMonth">/mes*</span>
                                </div>
                                <div class="mt-CardAdPrice-subscriptionLabel"><span class="mt-CardAdPrice-subscriptionLabel--highlight">IVA incluido</span></div>
                            </div>
                        </div>
                        <h2 class="mt-CardBasic-title mt-CardAd-title--oneLine" data-testid="card-ad-title">RENAULT Clio Evolution dCi 100 74kw 5p.</h2>
                        <ul class="mt-CardAd-attr">
                            <li class="mt-CardAd-attrItem">Diesel</li>
                            <li class="mt-CardAd-attrItem">2023</li>
                            <li class="mt-CardAd-attrItem">Manual</li>
                        </ul>
                        <ul class="mt-CardAd-tags">
                            <div class="sui-AtomBadge sui-AtomBadge-size-medium sui-AtomBadge-type-aquaWithoutHover sui-AtomBadge-design-soft"><span class="sui-AtomBadge-icon-text" title="En stock">En stock</span></div>
                            <div class="sui-AtomBadge sui-AtomBadge-size-medium sui-AtomBadge-type-gray sui-AtomBadge-design-soft"><span class="sui-AtomBadge-icon-text" title="Nuevo">Nuevo</span></div>
                        </ul>
                    </a></div>
            </div>
            <div class="mt-CardAd-fav">
                <div class="mt-CardAd-favIcon"><span class="sui-AtomIcon sui-AtomIcon--medium sui-AtomIcon--currentColor"><span><svg viewBox="0 0 24 24" xmlns="http://www.w3.org/2000/svg">
                                <path d="M6.607 3.057c1.93-.279 4.02.469 5.393 2.171 1.373-1.702 3.462-2.45 5.393-2.171a5.17 5.17 0 0 1 3.248 1.79C21.501 5.872 22 7.27 22 8.972c0 3.474-2.56 6.49-4.835 8.516a29.628 29.628 0 0 1-4.678 3.386 1 1 0 0 1-.974 0c-.14-.08-.279-.162-.417-.245a29.633 29.633 0 0 1-4.261-3.14C4.56 15.461 2 12.445 2 8.971c0-1.703.499-3.1 1.359-4.125a5.17 5.17 0 0 1 3.248-1.79Z"></path>
                            </svg></span></span></div>
            </div>
            <div class="mt-CardAd-footer">
                <div class="mt-CardAd-footerFinancingInfoContainer">* Permanencia: 48 meses · Kilómetros incluidos: 10.000 /año · También disponible: 36 y 60 meses</div>
            </div>
        </div>
    </div>
    <div data-ad-id="58052325">
        <div class="mt-AnimationFadeOut mt-ListAds-item mt-CardAd mt-CardBasic">
            <div class="sui-AtomCard sui-AtomCard--responsive" role="button">
                <div class="sui-AtomCard-media">
                    <div class="mt-CardAd-mediaContainer"><a class="mt-CardAd-media " href="/renting/seat/ibiza/10_mpi_59kw_80cv_reference_plus-gasolina-2019-58052325-vsre" target="_self" title="SEAT Ibiza 1.0 MPI 59kW 80CV Reference Plus 5p.">
                            <div class="sui-AtomImage is-loaded">
                                <figure class="sui-AtomImage-figure">
                                    <picture><img alt="SEAT Ibiza 1.0 MPI 59kW 80CV Reference Plus 5p." class="mt-CardAd-mediaImage" decoding="auto" fetchpriority="auto" loading="eager" height="189" src="https://a.ccdn.es/cnet/2024/06/12/58052325/1925191204_g.jpg/252x189cut/" width="252" title="SEAT Ibiza 1.0 MPI 59kW 80CV Reference Plus 5p."></picture>
                                </figure>
                            </div>
                        </a></div>
                </div>
                <div class="sui-AtomCard-info"><a href="/renting/seat/ibiza/10_mpi_59kw_80cv_reference_plus-gasolina-2019-58052325-vsre" class="mt-CardBasic-titleLink" title="SEAT Ibiza 1.0 MPI 59kW 80CV Reference Plus 5p." target="_self">
                        <div class="mt-CardAdPrice">
                            <div class="mt-CardAdPrice-subscription mt-CardAdPrice-subscription--fullwidth"><span class="mt-CardAdPrice-subscriptionLabel">Cuota desde</span>
                                <div class="mt-CardAdPrice-subscriptionAmount">
                                    <div class="mt-TitleBasic-titleWrapper mt-TitleBasic-titleWrapper--currentColor mt-TitleBasic-titleWrapper--left">
                                        <h3 class="mt-TitleBasic-title mt-TitleBasic-title--s mt-TitleBasic-title--currentColor">294&nbsp;€</h3>
                                    </div><span class="mt-CardAdPrice-subscriptionAmountPerMonth">/mes*</span>
                                </div>
                                <div class="mt-CardAdPrice-subscriptionLabel"><span class="mt-CardAdPrice-subscriptionLabel--highlight">IVA incluido</span></div>
                            </div>
                        </div>
                        <h2 class="mt-CardBasic-title mt-CardAd-title--oneLine" data-testid="card-ad-title">SEAT Ibiza 1.0 MPI 59kW 80CV Reference Plus 5p.</h2>
                        <ul class="mt-CardAd-attr">
                            <li class="mt-CardAd-attrItem">Gasolina</li>
                            <li class="mt-CardAd-attrItem">2020</li>
                            <li class="mt-CardAd-attrItem">Manual</li>
                        </ul>
                        <ul class="mt-CardAd-tags">
                            <div class="sui-AtomBadge sui-AtomBadge-size-medium sui-AtomBadge-type-gray sui-AtomBadge-design-soft"><span class="sui-AtomBadge-icon-text" title="Segunda mano">Segunda mano</span></div>
                        </ul>
                    </a></div>
            </div>
            <div class="mt-CardAd-fav">
                <div class="mt-CardAd-favIcon"><span class="sui-AtomIcon sui-AtomIcon--medium sui-AtomIcon--currentColor"><span><svg viewBox="0 0 24 24" xmlns="http://www.w3.org/2000/svg">
                                <path d="M6.607 3.057c1.93-.279 4.02.469 5.393 2.171 1.373-1.702 3.462-2.45 5.393-2.171a5.17 5.17 0 0 1 3.248 1.79C21.501 5.872 22 7.27 22 8.972c0 3.474-2.56 6.49-4.835 8.516a29.628 29.628 0 0 1-4.678 3.386 1 1 0 0 1-.974 0c-.14-.08-.279-.162-.417-.245a29.633 29.633 0 0 1-4.261-3.14C4.56 15.461 2 12.445 2 8.971c0-1.703.499-3.1 1.359-4.125a5.17 5.17 0 0 1 3.248-1.79Z"></path>
                            </svg></span></span></div>
            </div>
            <div class="mt-CardAd-footer">
                <div class="mt-CardAd-footerFinancingInfoContainer">* Permanencia: 12 meses · Kilómetros incluidos: 10.000 /año</div>
            </div>
        </div>
    </div>
    <div data-ad-id="58072769">
        <div class="mt-AnimationFadeOut mt-ListAds-item mt-CardAd mt-CardBasic">
            <div class="sui-AtomCard sui-AtomCard--responsive" role="button">
                <div class="sui-AtomCard-media">
                    <div class="mt-CardAd-mediaContainer"><a class="mt-CardAd-media " href="/renting/seat/ibiza/10_mpi_59kw_80cv_reference_plus-gasolina-2019-58072769-vsre" target="_self" title="SEAT Ibiza 1.0 MPI 59kW 80CV Reference Plus 5p.">
                            <div class="sui-AtomImage is-loaded">
                                <figure class="sui-AtomImage-figure">
                                    <picture><img alt="SEAT Ibiza 1.0 MPI 59kW 80CV Reference Plus 5p." class="mt-CardAd-mediaImage" decoding="auto" fetchpriority="auto" loading="eager" height="189" src="https://a.ccdn.es/cnet/2024/06/14/58072769/1925984373_g.jpg/252x189cut/" width="252" title="SEAT Ibiza 1.0 MPI 59kW 80CV Reference Plus 5p."></picture>
                                </figure>
                            </div>
                        </a></div>
                </div>
                <div class="sui-AtomCard-info"><a href="/renting/seat/ibiza/10_mpi_59kw_80cv_reference_plus-gasolina-2019-58072769-vsre" class="mt-CardBasic-titleLink" title="SEAT Ibiza 1.0 MPI 59kW 80CV Reference Plus 5p." target="_self">
                        <div class="mt-CardAdPrice">
                            <div class="mt-CardAdPrice-subscription mt-CardAdPrice-subscription--fullwidth"><span class="mt-CardAdPrice-subscriptionLabel">Cuota desde</span>
                                <div class="mt-CardAdPrice-subscriptionAmount">
                                    <div class="mt-TitleBasic-titleWrapper mt-TitleBasic-titleWrapper--currentColor mt-TitleBasic-titleWrapper--left">
                                        <h3 class="mt-TitleBasic-title mt-TitleBasic-title--s mt-TitleBasic-title--currentColor">294&nbsp;€</h3>
                                    </div><span class="mt-CardAdPrice-subscriptionAmountPerMonth">/mes*</span>
                                </div>
                                <div class="mt-CardAdPrice-subscriptionLabel"><span class="mt-CardAdPrice-subscriptionLabel--highlight">IVA incluido</span></div>
                            </div>
                        </div>
                        <h2 class="mt-CardBasic-title mt-CardAd-title--oneLine" data-testid="card-ad-title">SEAT Ibiza 1.0 MPI 59kW 80CV Reference Plus 5p.</h2>
                        <ul class="mt-CardAd-attr">
                            <li class="mt-CardAd-attrItem">Gasolina</li>
                            <li class="mt-CardAd-attrItem">2020</li>
                            <li class="mt-CardAd-attrItem">Manual</li>
                        </ul>
                        <ul class="mt-CardAd-tags">
                            <div class="sui-AtomBadge sui-AtomBadge-size-medium sui-AtomBadge-type-gray sui-AtomBadge-design-soft"><span class="sui-AtomBadge-icon-text" title="Segunda mano">Segunda mano</span></div>
                        </ul>
                    </a></div>
            </div>
            <div class="mt-CardAd-fav">
                <div class="mt-CardAd-favIcon"><span class="sui-AtomIcon sui-AtomIcon--medium sui-AtomIcon--currentColor"><span><svg viewBox="0 0 24 24" xmlns="http://www.w3.org/2000/svg">
                                <path d="M6.607 3.057c1.93-.279 4.02.469 5.393 2.171 1.373-1.702 3.462-2.45 5.393-2.171a5.17 5.17 0 0 1 3.248 1.79C21.501 5.872 22 7.27 22 8.972c0 3.474-2.56 6.49-4.835 8.516a29.628 29.628 0 0 1-4.678 3.386 1 1 0 0 1-.974 0c-.14-.08-.279-.162-.417-.245a29.633 29.633 0 0 1-4.261-3.14C4.56 15.461 2 12.445 2 8.971c0-1.703.499-3.1 1.359-4.125a5.17 5.17 0 0 1 3.248-1.79Z"></path>
                            </svg></span></span></div>
            </div>
            <div class="mt-CardAd-footer">
                <div class="mt-CardAd-footerFinancingInfoContainer">* Permanencia: 12 meses · Kilómetros incluidos: 10.000 /año</div>
            </div>
        </div>
    </div>
    <div class="mt-ListAds-item mt-ListAds-item mt-CardAd mt-CardBasic mt-ListAds-item--native--desktop">
        <div id="ad-inline-1-wrapper" class="adit-saitama-SaitamaAd">
            <div id="ad-inline-1" data-google-query-id="COnl3euR_oYDFU9ypAQdUwQFBg">
                <div id="google_ads_iframe_/124564242/Cochesnet/Cochesnet-web_desktop/cn-wde-renting-list-inline_1_0__container__" style="border: 0pt none; display: inline-block; width: 100%; height: auto;"><iframe frameborder="0" src="https://486d751287390a578ad223b6bcda3c26.safeframe.googlesyndication.com/safeframe/1-0-40/html/container.html" id="google_ads_iframe_/124564242/Cochesnet/Cochesnet-web_desktop/cn-wde-renting-list-inline_1_0" title="3rd party ad content" name="" scrolling="no" marginwidth="0" marginheight="0" width="0" height="206" data-is-safeframe="true" sandbox="allow-forms allow-popups allow-popups-to-escape-sandbox allow-same-origin allow-scripts allow-top-navigation-by-user-activation" allow="attribution-reporting" aria-label="Advertisement" tabindex="0" data-google-container-id="2" style="border: 0px; vertical-align: bottom; min-width: 100%;" data-load-complete="true"></iframe></div>
            </div>
        </div>
    </div>
    <div data-ad-id="55775850">
        <div class="mt-AnimationFadeOut mt-ListAds-item mt-CardAd mt-CardBasic">
            <div class="sui-AtomCard sui-AtomCard--responsive" role="button">
                <div class="sui-AtomCard-media">
                    <div class="mt-CardAd-mediaContainer"><a class="mt-CardAd-media " href="/renting/citroen/c4/puretech_130_ss_eat8_feel_pack-gasolina-2023-55775850-vsre" target="_self" title="CITROEN C4 PureTech 130 SS 6v Feel Pack 5p.">
                            <div class="sui-AtomImage is-loaded">
                                <figure class="sui-AtomImage-figure">
                                    <picture><img alt="CITROEN C4 PureTech 130 SS 6v Feel Pack 5p." class="mt-CardAd-mediaImage" decoding="auto" fetchpriority="auto" loading="eager" height="189" src="https://a.ccdn.es/cnet/2023/08/09/55775850/1899506022_g.jpg/252x189cut/" width="252" title="CITROEN C4 PureTech 130 SS 6v Feel Pack 5p."></picture>
                                </figure>
                            </div>
                        </a></div>
                </div>
                <div class="sui-AtomCard-info"><a href="/renting/citroen/c4/puretech_130_ss_eat8_feel_pack-gasolina-2023-55775850-vsre" class="mt-CardBasic-titleLink" title="CITROEN C4 PureTech 130 SS 6v Feel Pack 5p." target="_self">
                        <div class="mt-CardAdPrice">
                            <div class="mt-CardAdPrice-subscription mt-CardAdPrice-subscription--fullwidth">
                                <div class="mt-CardAdPrice-priceIndicator is-clickable">
                                    <div class="mt-CardAdPrice-priceIndicatorTitle"><span class="mt-CardAdPrice-cashLabel mt-CardAdPrice-cashLabel--noWrap">Buen precio</span></div>
                                    <div class="mt-CardAdPrice-priceIndicatorContainer mt-CardAdPrice-priceIndicatorContainer--small"><span class="mt-CardAdPrice-priceIndicatorContainerItem mt-CardAdPrice-priceIndicatorContainerItem--green"></span><span class="mt-CardAdPrice-priceIndicatorContainerItem mt-CardAdPrice-priceIndicatorContainerItem--green"></span><span class="mt-CardAdPrice-priceIndicatorContainerItem mt-CardAdPrice-priceIndicatorContainerItem--green"></span><span class="mt-CardAdPrice-priceIndicatorContainerItem mt-CardAdPrice-priceIndicatorContainerItem--green"></span><span class="mt-CardAdPrice-priceIndicatorContainerItem mt-CardAdPrice-priceIndicatorContainerItem--default"></span></div>
                                </div>
                                <div class="mt-CardAdPrice-subscriptionAmount">
                                    <div class="mt-TitleBasic-titleWrapper mt-TitleBasic-titleWrapper--currentColor mt-TitleBasic-titleWrapper--left">
                                        <h3 class="mt-TitleBasic-title mt-TitleBasic-title--s mt-TitleBasic-title--currentColor">362&nbsp;€</h3>
                                    </div><span class="mt-CardAdPrice-subscriptionAmountPerMonth">/mes*</span>
                                </div>
                                <div class="mt-CardAdPrice-subscriptionLabel"><span class="mt-CardAdPrice-subscriptionLabel--highlight">IVA incluido</span></div>
                            </div>
                        </div>
                        <h2 class="mt-CardBasic-title mt-CardAd-title--oneLine" data-testid="card-ad-title">CITROEN C4 PureTech 130 SS 6v Feel Pack 5p.</h2>
                        <ul class="mt-CardAd-attr">
                            <li class="mt-CardAd-attrItem">Gasolina</li>
                            <li class="mt-CardAd-attrItem">2023</li>
                            <li class="mt-CardAd-attrItem">Automático</li>
                        </ul>
                        <ul class="mt-CardAd-tags">
                            <div class="sui-AtomBadge sui-AtomBadge-size-medium sui-AtomBadge-type-gray sui-AtomBadge-design-soft"><span class="sui-AtomBadge-icon-text" title="Nuevo">Nuevo</span></div>
                        </ul>
                    </a></div>
            </div>
            <div class="mt-CardAd-fav">
                <div class="mt-CardAd-favIcon"><span class="sui-AtomIcon sui-AtomIcon--medium sui-AtomIcon--currentColor"><span><svg viewBox="0 0 24 24" xmlns="http://www.w3.org/2000/svg">
                                <path d="M6.607 3.057c1.93-.279 4.02.469 5.393 2.171 1.373-1.702 3.462-2.45 5.393-2.171a5.17 5.17 0 0 1 3.248 1.79C21.501 5.872 22 7.27 22 8.972c0 3.474-2.56 6.49-4.835 8.516a29.628 29.628 0 0 1-4.678 3.386 1 1 0 0 1-.974 0c-.14-.08-.279-.162-.417-.245a29.633 29.633 0 0 1-4.261-3.14C4.56 15.461 2 12.445 2 8.971c0-1.703.499-3.1 1.359-4.125a5.17 5.17 0 0 1 3.248-1.79Z"></path>
                            </svg></span></span></div>
            </div>
            <div class="mt-CardAd-footer">
                <div class="mt-CardAd-footerFinancingInfoContainer">* Permanencia: 60 meses · Kilómetros incluidos: 10.000 /año · También disponible: 36 y 48 meses</div>
            </div>
        </div>
    </div>
    <div data-ad-id="58172185">
        <div class="mt-AnimationFadeOut mt-ListAds-item mt-CardAd mt-CardBasic">
            <div class="sui-AtomCard sui-AtomCard--responsive" role="button">
                <div class="sui-AtomCard-media">
                    <div class="mt-CardAd-mediaContainer"><a class="mt-CardAd-media " href="/renting/citroen/c4/bluehdi_110_ss_live_pack-diesel-2022-58172185-vsre" target="_self" title="CITROEN C4 BlueHDi 110 SS Live Pack 5p.">
                            <div class="sui-AtomImage is-loaded">
                                <figure class="sui-AtomImage-figure">
                                    <picture><img alt="CITROEN C4 BlueHDi 110 SS Live Pack 5p." class="mt-CardAd-mediaImage" decoding="auto" fetchpriority="auto" loading="eager" height="189" src="https://a.ccdn.es/cnet/2024/06/28/58172185/1930024804_g.jpg/252x189cut/" width="252" title="CITROEN C4 BlueHDi 110 SS Live Pack 5p."></picture>
                                </figure>
                            </div>
                        </a></div>
                </div>
                <div class="sui-AtomCard-info"><a href="/renting/citroen/c4/bluehdi_110_ss_live_pack-diesel-2022-58172185-vsre" class="mt-CardBasic-titleLink" title="CITROEN C4 BlueHDi 110 SS Live Pack 5p." target="_self">
                        <div class="mt-CardAdPrice">
                            <div class="mt-CardAdPrice-subscription mt-CardAdPrice-subscription--fullwidth"><span class="mt-CardAdPrice-subscriptionLabel">Cuota desde</span>
                                <div class="mt-CardAdPrice-subscriptionAmount">
                                    <div class="mt-TitleBasic-titleWrapper mt-TitleBasic-titleWrapper--currentColor mt-TitleBasic-titleWrapper--left">
                                        <h3 class="mt-TitleBasic-title mt-TitleBasic-title--s mt-TitleBasic-title--currentColor">393&nbsp;€</h3>
                                    </div><span class="mt-CardAdPrice-subscriptionAmountPerMonth">/mes*</span>
                                </div>
                                <div class="mt-CardAdPrice-subscriptionLabel"><span class="mt-CardAdPrice-subscriptionLabel--highlight">IVA incluido</span></div>
                            </div>
                        </div>
                        <h2 class="mt-CardBasic-title mt-CardAd-title--oneLine" data-testid="card-ad-title">CITROEN C4 BlueHDi 110 SS Live Pack 5p.</h2>
                        <ul class="mt-CardAd-attr">
                            <li class="mt-CardAd-attrItem">Diesel</li>
                            <li class="mt-CardAd-attrItem">2022</li>
                            <li class="mt-CardAd-attrItem">Manual</li>
                        </ul>
                        <ul class="mt-CardAd-tags">
                            <div class="sui-AtomBadge sui-AtomBadge-size-medium sui-AtomBadge-type-gray sui-AtomBadge-design-soft"><span class="sui-AtomBadge-icon-text" title="Segunda mano">Segunda mano</span></div>
                        </ul>
                    </a></div>
            </div>
            <div class="mt-CardAd-fav">
                <div class="mt-CardAd-favIcon"><span class="sui-AtomIcon sui-AtomIcon--medium sui-AtomIcon--currentColor"><span><svg viewBox="0 0 24 24" xmlns="http://www.w3.org/2000/svg">
                                <path d="M6.607 3.057c1.93-.279 4.02.469 5.393 2.171 1.373-1.702 3.462-2.45 5.393-2.171a5.17 5.17 0 0 1 3.248 1.79C21.501 5.872 22 7.27 22 8.972c0 3.474-2.56 6.49-4.835 8.516a29.628 29.628 0 0 1-4.678 3.386 1 1 0 0 1-.974 0c-.14-.08-.279-.162-.417-.245a29.633 29.633 0 0 1-4.261-3.14C4.56 15.461 2 12.445 2 8.971c0-1.703.499-3.1 1.359-4.125a5.17 5.17 0 0 1 3.248-1.79Z"></path>
                            </svg></span></span></div>
            </div>
            <div class="mt-CardAd-footer">
                <div class="mt-CardAd-footerFinancingInfoContainer">* Permanencia: 12 meses · Kilómetros incluidos: 10.000 /año</div>
            </div>
        </div>
    </div>
    <div data-ad-id="58052381">
        <div class="mt-AnimationFadeOut mt-ListAds-item mt-CardAd mt-CardBasic">
            <div class="sui-AtomCard sui-AtomCard--responsive" role="button">
                <div class="sui-AtomCard-media">
                    <div class="mt-CardAd-mediaContainer"><a class="mt-CardAd-media " href="/renting/renault/clio/limited_dci_55kw_75cv_18-diesel-2019-58052381-vsre" target="_self" title="RENAULT Clio Limited dCi 55kW 75CV 18 5p.">
                            <div class="sui-AtomImage is-loaded">
                                <figure class="sui-AtomImage-figure">
                                    <picture><img alt="RENAULT Clio Limited dCi 55kW 75CV 18 5p." class="mt-CardAd-mediaImage" decoding="auto" fetchpriority="auto" loading="eager" height="189" src="https://a.ccdn.es/cnet/2024/06/12/58052381/1925191874_g.jpg/252x189cut/" width="252" title="RENAULT Clio Limited dCi 55kW 75CV 18 5p."></picture>
                                </figure>
                            </div>
                        </a></div>
                </div>
                <div class="sui-AtomCard-info"><a href="/renting/renault/clio/limited_dci_55kw_75cv_18-diesel-2019-58052381-vsre" class="mt-CardBasic-titleLink" title="RENAULT Clio Limited dCi 55kW 75CV 18 5p." target="_self">
                        <div class="mt-CardAdPrice">
                            <div class="mt-CardAdPrice-subscription mt-CardAdPrice-subscription--fullwidth"><span class="mt-CardAdPrice-subscriptionLabel">Cuota desde</span>
                                <div class="mt-CardAdPrice-subscriptionAmount">
                                    <div class="mt-TitleBasic-titleWrapper mt-TitleBasic-titleWrapper--currentColor mt-TitleBasic-titleWrapper--left">
                                        <h3 class="mt-TitleBasic-title mt-TitleBasic-title--s mt-TitleBasic-title--currentColor">294&nbsp;€</h3>
                                    </div><span class="mt-CardAdPrice-subscriptionAmountPerMonth">/mes*</span>
                                </div>
                                <div class="mt-CardAdPrice-subscriptionLabel"><span class="mt-CardAdPrice-subscriptionLabel--highlight">IVA incluido</span></div>
                            </div>
                        </div>
                        <h2 class="mt-CardBasic-title mt-CardAd-title--oneLine" data-testid="card-ad-title">RENAULT Clio Limited dCi 55kW 75CV 18 5p.</h2>
                        <ul class="mt-CardAd-attr">
                            <li class="mt-CardAd-attrItem">Diesel</li>
                            <li class="mt-CardAd-attrItem">2019</li>
                            <li class="mt-CardAd-attrItem">Manual</li>
                        </ul>
                        <ul class="mt-CardAd-tags">
                            <div class="sui-AtomBadge sui-AtomBadge-size-medium sui-AtomBadge-type-gray sui-AtomBadge-design-soft"><span class="sui-AtomBadge-icon-text" title="Segunda mano">Segunda mano</span></div>
                        </ul>
                    </a></div>
            </div>
            <div class="mt-CardAd-fav">
                <div class="mt-CardAd-favIcon"><span class="sui-AtomIcon sui-AtomIcon--medium sui-AtomIcon--currentColor"><span><svg viewBox="0 0 24 24" xmlns="http://www.w3.org/2000/svg">
                                <path d="M6.607 3.057c1.93-.279 4.02.469 5.393 2.171 1.373-1.702 3.462-2.45 5.393-2.171a5.17 5.17 0 0 1 3.248 1.79C21.501 5.872 22 7.27 22 8.972c0 3.474-2.56 6.49-4.835 8.516a29.628 29.628 0 0 1-4.678 3.386 1 1 0 0 1-.974 0c-.14-.08-.279-.162-.417-.245a29.633 29.633 0 0 1-4.261-3.14C4.56 15.461 2 12.445 2 8.971c0-1.703.499-3.1 1.359-4.125a5.17 5.17 0 0 1 3.248-1.79Z"></path>
                            </svg></span></span></div>
            </div>
            <div class="mt-CardAd-footer">
                <div class="mt-CardAd-footerFinancingInfoContainer">* Permanencia: 12 meses · Kilómetros incluidos: 10.000 /año</div>
            </div>
        </div>
    </div>
    <div data-ad-id="58154995">
        <div class="mt-AnimationFadeOut mt-ListAds-item mt-CardAd mt-CardBasic">
            <div class="sui-AtomCard sui-AtomCard--responsive" role="button">
                <div class="sui-AtomCard-media">
                    <div class="mt-CardAd-mediaContainer"><a class="mt-CardAd-media " href="/renting/renault/clio/limited_dci_55kw_75cv_18-diesel-2019-58154995-vsre" target="_self" title="RENAULT Clio Limited dCi 55kW 75CV 18 5p.">
                            <div class="sui-AtomImage is-loaded">
                                <figure class="sui-AtomImage-figure">
                                    <picture><img alt="RENAULT Clio Limited dCi 55kW 75CV 18 5p." class="mt-CardAd-mediaImage" decoding="auto" fetchpriority="auto" loading="eager" height="189" src="https://a.ccdn.es/cnet/2024/06/26/58154995/1929260634_g.jpg/252x189cut/" width="252" title="RENAULT Clio Limited dCi 55kW 75CV 18 5p."></picture>
                                </figure>
                            </div>
                        </a></div>
                </div>
                <div class="sui-AtomCard-info"><a href="/renting/renault/clio/limited_dci_55kw_75cv_18-diesel-2019-58154995-vsre" class="mt-CardBasic-titleLink" title="RENAULT Clio Limited dCi 55kW 75CV 18 5p." target="_self">
                        <div class="mt-CardAdPrice">
                            <div class="mt-CardAdPrice-subscription mt-CardAdPrice-subscription--fullwidth"><span class="mt-CardAdPrice-subscriptionLabel">Cuota desde</span>
                                <div class="mt-CardAdPrice-subscriptionAmount">
                                    <div class="mt-TitleBasic-titleWrapper mt-TitleBasic-titleWrapper--currentColor mt-TitleBasic-titleWrapper--left">
                                        <h3 class="mt-TitleBasic-title mt-TitleBasic-title--s mt-TitleBasic-title--currentColor">294&nbsp;€</h3>
                                    </div><span class="mt-CardAdPrice-subscriptionAmountPerMonth">/mes*</span>
                                </div>
                                <div class="mt-CardAdPrice-subscriptionLabel"><span class="mt-CardAdPrice-subscriptionLabel--highlight">IVA incluido</span></div>
                            </div>
                        </div>
                        <h2 class="mt-CardBasic-title mt-CardAd-title--oneLine" data-testid="card-ad-title">RENAULT Clio Limited dCi 55kW 75CV 18 5p.</h2>
                        <ul class="mt-CardAd-attr">
                            <li class="mt-CardAd-attrItem">Diesel</li>
                            <li class="mt-CardAd-attrItem">2019</li>
                            <li class="mt-CardAd-attrItem">Manual</li>
                        </ul>
                        <ul class="mt-CardAd-tags">
                            <div class="sui-AtomBadge sui-AtomBadge-size-medium sui-AtomBadge-type-gray sui-AtomBadge-design-soft"><span class="sui-AtomBadge-icon-text" title="Segunda mano">Segunda mano</span></div>
                        </ul>
                    </a></div>
            </div>
            <div class="mt-CardAd-fav">
                <div class="mt-CardAd-favIcon"><span class="sui-AtomIcon sui-AtomIcon--medium sui-AtomIcon--currentColor"><span><svg viewBox="0 0 24 24" xmlns="http://www.w3.org/2000/svg">
                                <path d="M6.607 3.057c1.93-.279 4.02.469 5.393 2.171 1.373-1.702 3.462-2.45 5.393-2.171a5.17 5.17 0 0 1 3.248 1.79C21.501 5.872 22 7.27 22 8.972c0 3.474-2.56 6.49-4.835 8.516a29.628 29.628 0 0 1-4.678 3.386 1 1 0 0 1-.974 0c-.14-.08-.279-.162-.417-.245a29.633 29.633 0 0 1-4.261-3.14C4.56 15.461 2 12.445 2 8.971c0-1.703.499-3.1 1.359-4.125a5.17 5.17 0 0 1 3.248-1.79Z"></path>
                            </svg></span></span></div>
            </div>
            <div class="mt-CardAd-footer">
                <div class="mt-CardAd-footerFinancingInfoContainer">* Permanencia: 12 meses · Kilómetros incluidos: 10.000 /año</div>
            </div>
        </div>
    </div>
    <div data-ad-id="57009294">
        <div class="mt-AnimationFadeOut mt-ListAds-item mt-CardAd mt-CardBasic">
            <div class="sui-AtomCard sui-AtomCard--responsive" role="button">
                <div class="sui-AtomCard-media">
                    <div class="mt-CardAd-mediaContainer"><a class="mt-CardAd-media " href="/renting/skoda/octavia/15_tsi_mhev_110kw150cv_dsg_selection-otros-2024-57009294-vsre" target="_self" title="SKODA Octavia 1.5 TSI mHEV 110kW150CV DSG Selection 5p.">
                            <div class="sui-AtomImage is-loaded">
                                <figure class="sui-AtomImage-figure">
                                    <picture><img alt="SKODA Octavia 1.5 TSI mHEV 110kW150CV DSG Selection 5p." class="mt-CardAd-mediaImage" decoding="auto" fetchpriority="auto" loading="eager" height="189" src="https://a.ccdn.es/cnet/2024/01/30/57009294/1899141455_g.jpg/252x189cut/" width="252" title="SKODA Octavia 1.5 TSI mHEV 110kW150CV DSG Selection 5p."></picture>
                                </figure>
                            </div>
                        </a></div>
                </div>
                <div class="sui-AtomCard-info"><a href="/renting/skoda/octavia/15_tsi_mhev_110kw150cv_dsg_selection-otros-2024-57009294-vsre" class="mt-CardBasic-titleLink" title="SKODA Octavia 1.5 TSI mHEV 110kW150CV DSG Selection 5p." target="_self">
                        <div class="mt-CardAdPrice">
                            <div class="mt-CardAdPrice-subscription mt-CardAdPrice-subscription--fullwidth">
                                <div class="mt-CardAdPrice-priceIndicator is-clickable">
                                    <div class="mt-CardAdPrice-priceIndicatorTitle"><span class="mt-CardAdPrice-cashLabel mt-CardAdPrice-cashLabel--noWrap">Super precio</span></div>
                                    <div class="mt-CardAdPrice-priceIndicatorContainer mt-CardAdPrice-priceIndicatorContainer--small"><span class="mt-CardAdPrice-priceIndicatorContainerItem mt-CardAdPrice-priceIndicatorContainerItem--green"></span><span class="mt-CardAdPrice-priceIndicatorContainerItem mt-CardAdPrice-priceIndicatorContainerItem--green"></span><span class="mt-CardAdPrice-priceIndicatorContainerItem mt-CardAdPrice-priceIndicatorContainerItem--green"></span><span class="mt-CardAdPrice-priceIndicatorContainerItem mt-CardAdPrice-priceIndicatorContainerItem--green"></span><span class="mt-CardAdPrice-priceIndicatorContainerItem mt-CardAdPrice-priceIndicatorContainerItem--green"></span></div>
                                </div>
                                <div class="mt-CardAdPrice-subscriptionAmount">
                                    <div class="mt-TitleBasic-titleWrapper mt-TitleBasic-titleWrapper--currentColor mt-TitleBasic-titleWrapper--left">
                                        <h3 class="mt-TitleBasic-title mt-TitleBasic-title--s mt-TitleBasic-title--currentColor">395&nbsp;€</h3>
                                    </div><span class="mt-CardAdPrice-subscriptionAmountPerMonth">/mes*</span>
                                </div>
                                <div class="mt-CardAdPrice-subscriptionLabel"><span class="mt-CardAdPrice-subscriptionLabel--highlight">IVA incluido</span></div>
                            </div>
                        </div>
                        <h2 class="mt-CardBasic-title mt-CardAd-title--oneLine" data-testid="card-ad-title">SKODA Octavia 1.5 TSI mHEV 110kW150CV DSG Selection 5p.</h2>
                        <ul class="mt-CardAd-attr">
                            <li class="mt-CardAd-attrItem">Híbrido</li>
                            <li class="mt-CardAd-attrItem">2023</li>
                            <li class="mt-CardAd-attrItem">Automático</li>
                        </ul>
                        <ul class="mt-CardAd-tags">
                            <div class="sui-AtomBadge sui-AtomBadge-size-medium sui-AtomBadge-type-gray sui-AtomBadge-design-soft"><span class="sui-AtomBadge-icon-text" title="Nuevo">Nuevo</span></div>
                        </ul>
                    </a></div>
            </div>
            <div class="mt-CardAd-fav">
                <div class="mt-CardAd-favIcon"><span class="sui-AtomIcon sui-AtomIcon--medium sui-AtomIcon--currentColor"><span><svg viewBox="0 0 24 24" xmlns="http://www.w3.org/2000/svg">
                                <path d="M6.607 3.057c1.93-.279 4.02.469 5.393 2.171 1.373-1.702 3.462-2.45 5.393-2.171a5.17 5.17 0 0 1 3.248 1.79C21.501 5.872 22 7.27 22 8.972c0 3.474-2.56 6.49-4.835 8.516a29.628 29.628 0 0 1-4.678 3.386 1 1 0 0 1-.974 0c-.14-.08-.279-.162-.417-.245a29.633 29.633 0 0 1-4.261-3.14C4.56 15.461 2 12.445 2 8.971c0-1.703.499-3.1 1.359-4.125a5.17 5.17 0 0 1 3.248-1.79Z"></path>
                            </svg></span></span></div>
            </div>
            <div class="mt-CardAd-footer">
                <div class="mt-CardAd-footerFinancingInfoContainer">* Permanencia: 48 meses · Kilómetros incluidos: 10.000 /año · También disponible: 36 meses</div>
            </div>
        </div>
    </div>
    <div data-ad-id="58172178">
        <div class="mt-AnimationFadeOut mt-ListAds-item mt-CardAd mt-CardBasic">
            <div class="sui-AtomCard sui-AtomCard--responsive" role="button">
                <div class="sui-AtomCard-media">
                    <div class="mt-CardAd-mediaContainer"><a class="mt-CardAd-media " href="/renting/citroen/c3/bluehdi_73kw_100cv_ss_feel-diesel-2019-58172178-vsre" target="_self" title="CITROEN C3 BlueHDi 73KW 100CV SS FEEL 5p.">
                            <div class="sui-AtomImage is-loaded">
                                <figure class="sui-AtomImage-figure">
                                    <picture><img alt="CITROEN C3 BlueHDi 73KW 100CV SS FEEL 5p." class="mt-CardAd-mediaImage" decoding="auto" fetchpriority="auto" loading="eager" height="189" src="https://a.ccdn.es/cnet/2024/06/28/58172178/1930024764_g.jpg/252x189cut/" width="252" title="CITROEN C3 BlueHDi 73KW 100CV SS FEEL 5p."></picture>
                                </figure>
                            </div>
                        </a></div>
                </div>
                <div class="sui-AtomCard-info"><a href="/renting/citroen/c3/bluehdi_73kw_100cv_ss_feel-diesel-2019-58172178-vsre" class="mt-CardBasic-titleLink" title="CITROEN C3 BlueHDi 73KW 100CV SS FEEL 5p." target="_self">
                        <div class="mt-CardAdPrice">
                            <div class="mt-CardAdPrice-subscription mt-CardAdPrice-subscription--fullwidth"><span class="mt-CardAdPrice-subscriptionLabel">Cuota desde</span>
                                <div class="mt-CardAdPrice-subscriptionAmount">
                                    <div class="mt-TitleBasic-titleWrapper mt-TitleBasic-titleWrapper--currentColor mt-TitleBasic-titleWrapper--left">
                                        <h3 class="mt-TitleBasic-title mt-TitleBasic-title--s mt-TitleBasic-title--currentColor">293&nbsp;€</h3>
                                    </div><span class="mt-CardAdPrice-subscriptionAmountPerMonth">/mes*</span>
                                </div>
                                <div class="mt-CardAdPrice-subscriptionLabel"><span class="mt-CardAdPrice-subscriptionLabel--highlight">IVA incluido</span></div>
                            </div>
                        </div>
                        <h2 class="mt-CardBasic-title mt-CardAd-title--oneLine" data-testid="card-ad-title">CITROEN C3 BlueHDi 73KW 100CV SS FEEL 5p.</h2>
                        <ul class="mt-CardAd-attr">
                            <li class="mt-CardAd-attrItem">Diesel</li>
                            <li class="mt-CardAd-attrItem">2019</li>
                            <li class="mt-CardAd-attrItem">Manual</li>
                        </ul>
                        <ul class="mt-CardAd-tags">
                            <div class="sui-AtomBadge sui-AtomBadge-size-medium sui-AtomBadge-type-gray sui-AtomBadge-design-soft"><span class="sui-AtomBadge-icon-text" title="Segunda mano">Segunda mano</span></div>
                        </ul>
                    </a></div>
            </div>
            <div class="mt-CardAd-fav">
                <div class="mt-CardAd-favIcon"><span class="sui-AtomIcon sui-AtomIcon--medium sui-AtomIcon--currentColor"><span><svg viewBox="0 0 24 24" xmlns="http://www.w3.org/2000/svg">
                                <path d="M6.607 3.057c1.93-.279 4.02.469 5.393 2.171 1.373-1.702 3.462-2.45 5.393-2.171a5.17 5.17 0 0 1 3.248 1.79C21.501 5.872 22 7.27 22 8.972c0 3.474-2.56 6.49-4.835 8.516a29.628 29.628 0 0 1-4.678 3.386 1 1 0 0 1-.974 0c-.14-.08-.279-.162-.417-.245a29.633 29.633 0 0 1-4.261-3.14C4.56 15.461 2 12.445 2 8.971c0-1.703.499-3.1 1.359-4.125a5.17 5.17 0 0 1 3.248-1.79Z"></path>
                            </svg></span></span></div>
            </div>
            <div class="mt-CardAd-footer">
                <div class="mt-CardAd-footerFinancingInfoContainer">* Permanencia: 12 meses · Kilómetros incluidos: 10.000 /año</div>
            </div>
        </div>
    </div>
    <div data-ad-id="58122850">
        <div class="mt-AnimationFadeOut mt-ListAds-item mt-CardAd mt-CardBasic">
            <div class="sui-AtomCard sui-AtomCard--responsive" role="button">
                <div class="sui-AtomCard-media">
                    <div class="mt-CardAd-mediaContainer"><a class="mt-CardAd-media " href="/renting/mitsubishi/space_star/120_mpi_motion-gasolina-2023-58122850-vsre" target="_self" title="MITSUBISHI Space Star 120 MPI Motion 5p.">
                            <div class="sui-AtomImage is-loaded">
                                <figure class="sui-AtomImage-figure">
                                    <picture><img alt="MITSUBISHI Space Star 120 MPI Motion 5p." class="mt-CardAd-mediaImage" decoding="auto" fetchpriority="auto" loading="eager" height="189" src="https://a.ccdn.es/cnet/2024/06/21/58122850/1927869553_g.jpg/252x189cut/" width="252" title="MITSUBISHI Space Star 120 MPI Motion 5p."></picture>
                                </figure>
                            </div>
                        </a></div>
                </div>
                <div class="sui-AtomCard-info"><a href="/renting/mitsubishi/space_star/120_mpi_motion-gasolina-2023-58122850-vsre" class="mt-CardBasic-titleLink" title="MITSUBISHI Space Star 120 MPI Motion 5p." target="_self">
                        <div class="mt-CardAdPrice">
                            <div class="mt-CardAdPrice-subscription mt-CardAdPrice-subscription--fullwidth"><span class="mt-CardAdPrice-subscriptionLabel">Cuota desde</span>
                                <div class="mt-CardAdPrice-subscriptionAmount">
                                    <div class="mt-TitleBasic-titleWrapper mt-TitleBasic-titleWrapper--currentColor mt-TitleBasic-titleWrapper--left">
                                        <h3 class="mt-TitleBasic-title mt-TitleBasic-title--s mt-TitleBasic-title--currentColor">339&nbsp;€</h3>
                                    </div><span class="mt-CardAdPrice-subscriptionAmountPerMonth">/mes*</span>
                                </div>
                                <div class="mt-CardAdPrice-subscriptionLabel"><span class="mt-CardAdPrice-subscriptionLabel--highlight">IVA incluido</span></div>
                            </div>
                        </div>
                        <h2 class="mt-CardBasic-title mt-CardAd-title--oneLine" data-testid="card-ad-title">MITSUBISHI Space Star 120 MPI Motion 5p.</h2>
                        <ul class="mt-CardAd-attr">
                            <li class="mt-CardAd-attrItem">Gasolina</li>
                            <li class="mt-CardAd-attrItem">2023</li>
                            <li class="mt-CardAd-attrItem">Manual</li>
                        </ul>
                        <ul class="mt-CardAd-tags">
                            <div class="sui-AtomBadge sui-AtomBadge-size-medium sui-AtomBadge-type-gray sui-AtomBadge-design-soft"><span class="sui-AtomBadge-icon-text" title="Segunda mano">Segunda mano</span></div>
                        </ul>
                    </a></div>
            </div>
            <div class="mt-CardAd-fav">
                <div class="mt-CardAd-favIcon"><span class="sui-AtomIcon sui-AtomIcon--medium sui-AtomIcon--currentColor"><span><svg viewBox="0 0 24 24" xmlns="http://www.w3.org/2000/svg">
                                <path d="M6.607 3.057c1.93-.279 4.02.469 5.393 2.171 1.373-1.702 3.462-2.45 5.393-2.171a5.17 5.17 0 0 1 3.248 1.79C21.501 5.872 22 7.27 22 8.972c0 3.474-2.56 6.49-4.835 8.516a29.628 29.628 0 0 1-4.678 3.386 1 1 0 0 1-.974 0c-.14-.08-.279-.162-.417-.245a29.633 29.633 0 0 1-4.261-3.14C4.56 15.461 2 12.445 2 8.971c0-1.703.499-3.1 1.359-4.125a5.17 5.17 0 0 1 3.248-1.79Z"></path>
                            </svg></span></span></div>
            </div>
            <div class="mt-CardAd-footer">
                <div class="mt-CardAd-footerFinancingInfoContainer">* Permanencia: 12 meses · Kilómetros incluidos: 1.500 /mes · También disponible: 1, 3 y 6 meses</div>
            </div>
        </div>
    </div>
    <div data-ad-id="56323259">
        <div class="mt-AnimationFadeOut mt-ListAds-item mt-CardAd mt-CardBasic">
            <div class="sui-AtomCard sui-AtomCard--responsive" role="button">
                <div class="sui-AtomCard-media">
                    <div class="mt-CardAd-mediaContainer"><a class="mt-CardAd-media " href="/renting/kia/picanto/10_dpi_49kw_67cv_gt_line-gasolina-2023-56323259-vsre" target="_self" title="KIA Picanto 1.0 DPi 49kW 67CV GT Line 5p.">
                            <div class="sui-AtomImage is-loaded">
                                <figure class="sui-AtomImage-figure">
                                    <picture><img alt="KIA Picanto 1.0 DPi 49kW 67CV GT Line 5p." class="mt-CardAd-mediaImage" decoding="auto" fetchpriority="auto" loading="eager" height="189" src="https://a.ccdn.es/cnet/2023/10/26/56323259/1899194860_g.jpg/252x189cut/" width="252" title="KIA Picanto 1.0 DPi 49kW 67CV GT Line 5p."></picture>
                                </figure>
                            </div>
                        </a></div>
                </div>
                <div class="sui-AtomCard-info"><a href="/renting/kia/picanto/10_dpi_49kw_67cv_gt_line-gasolina-2023-56323259-vsre" class="mt-CardBasic-titleLink" title="KIA Picanto 1.0 DPi 49kW 67CV GT Line 5p." target="_self">
                        <div class="mt-CardAdPrice">
                            <div class="mt-CardAdPrice-subscription mt-CardAdPrice-subscription--fullwidth">
                                <div class="mt-CardAdPrice-priceIndicator is-clickable">
                                    <div class="mt-CardAdPrice-priceIndicatorTitle"><span class="mt-CardAdPrice-cashLabel mt-CardAdPrice-cashLabel--noWrap">Precio justo</span></div>
                                    <div class="mt-CardAdPrice-priceIndicatorContainer mt-CardAdPrice-priceIndicatorContainer--small"><span class="mt-CardAdPrice-priceIndicatorContainerItem mt-CardAdPrice-priceIndicatorContainerItem--green"></span><span class="mt-CardAdPrice-priceIndicatorContainerItem mt-CardAdPrice-priceIndicatorContainerItem--green"></span><span class="mt-CardAdPrice-priceIndicatorContainerItem mt-CardAdPrice-priceIndicatorContainerItem--green"></span><span class="mt-CardAdPrice-priceIndicatorContainerItem mt-CardAdPrice-priceIndicatorContainerItem--default"></span><span class="mt-CardAdPrice-priceIndicatorContainerItem mt-CardAdPrice-priceIndicatorContainerItem--default"></span></div>
                                </div>
                                <div class="mt-CardAdPrice-subscriptionAmount">
                                    <div class="mt-TitleBasic-titleWrapper mt-TitleBasic-titleWrapper--currentColor mt-TitleBasic-titleWrapper--left">
                                        <h3 class="mt-TitleBasic-title mt-TitleBasic-title--s mt-TitleBasic-title--currentColor">308&nbsp;€</h3>
                                    </div><span class="mt-CardAdPrice-subscriptionAmountPerMonth">/mes*</span>
                                </div>
                                <div class="mt-CardAdPrice-subscriptionLabel"><span class="mt-CardAdPrice-subscriptionLabel--highlight">IVA incluido</span></div>
                            </div>
                        </div>
                        <h2 class="mt-CardBasic-title mt-CardAd-title--oneLine" data-testid="card-ad-title">KIA Picanto 1.0 DPi 49kW 67CV GT Line 5p.</h2>
                        <ul class="mt-CardAd-attr">
                            <li class="mt-CardAd-attrItem">Gasolina</li>
                            <li class="mt-CardAd-attrItem">2023</li>
                            <li class="mt-CardAd-attrItem">Manual</li>
                        </ul>
                        <ul class="mt-CardAd-tags">
                            <div class="sui-AtomBadge sui-AtomBadge-size-medium sui-AtomBadge-type-gray sui-AtomBadge-design-soft"><span class="sui-AtomBadge-icon-text" title="Nuevo">Nuevo</span></div>
                        </ul>
                    </a></div>
            </div>
            <div class="mt-CardAd-fav">
                <div class="mt-CardAd-favIcon"><span class="sui-AtomIcon sui-AtomIcon--medium sui-AtomIcon--currentColor"><span><svg viewBox="0 0 24 24" xmlns="http://www.w3.org/2000/svg">
                                <path d="M6.607 3.057c1.93-.279 4.02.469 5.393 2.171 1.373-1.702 3.462-2.45 5.393-2.171a5.17 5.17 0 0 1 3.248 1.79C21.501 5.872 22 7.27 22 8.972c0 3.474-2.56 6.49-4.835 8.516a29.628 29.628 0 0 1-4.678 3.386 1 1 0 0 1-.974 0c-.14-.08-.279-.162-.417-.245a29.633 29.633 0 0 1-4.261-3.14C4.56 15.461 2 12.445 2 8.971c0-1.703.499-3.1 1.359-4.125a5.17 5.17 0 0 1 3.248-1.79Z"></path>
                            </svg></span></span></div>
            </div>
            <div class="mt-CardAd-footer">
                <div class="mt-CardAd-footerFinancingInfoContainer">* Permanencia: 60 meses · Kilómetros incluidos: 10.000 /año · También disponible: 36 y 48 meses</div>
            </div>
        </div>
    </div>
    <div data-ad-id="57920099">
        <div class="mt-AnimationFadeOut mt-ListAds-item mt-CardAd mt-CardBasic">
            <div class="sui-AtomCard sui-AtomCard--responsive" role="button">
                <div class="sui-AtomCard-media">
                    <div class="mt-CardAd-mediaContainer"><a class="mt-CardAd-media " href="/renting/ford/focus/15_ecoblue_88kw_trend-diesel-2020-57920099-vsre" target="_self" title="FORD Focus 1.5 Ecoblue 88kW Trend 5p.">
                            <div class="sui-AtomImage is-loaded">
                                <figure class="sui-AtomImage-figure">
                                    <picture><img alt="FORD Focus 1.5 Ecoblue 88kW Trend 5p." class="mt-CardAd-mediaImage" decoding="auto" fetchpriority="auto" loading="eager" height="189" src="https://a.ccdn.es/cnet/2024/05/27/57920099/1920530378_g.jpg/252x189cut/" width="252" title="FORD Focus 1.5 Ecoblue 88kW Trend 5p."></picture>
                                </figure>
                            </div>
                        </a></div>
                </div>
                <div class="sui-AtomCard-info"><a href="/renting/ford/focus/15_ecoblue_88kw_trend-diesel-2020-57920099-vsre" class="mt-CardBasic-titleLink" title="FORD Focus 1.5 Ecoblue 88kW Trend 5p." target="_self">
                        <div class="mt-CardAdPrice">
                            <div class="mt-CardAdPrice-subscription mt-CardAdPrice-subscription--fullwidth"><span class="mt-CardAdPrice-subscriptionLabel">Cuota desde</span>
                                <div class="mt-CardAdPrice-subscriptionAmount">
                                    <div class="mt-TitleBasic-titleWrapper mt-TitleBasic-titleWrapper--currentColor mt-TitleBasic-titleWrapper--left">
                                        <h3 class="mt-TitleBasic-title mt-TitleBasic-title--s mt-TitleBasic-title--currentColor">370&nbsp;€</h3>
                                    </div><span class="mt-CardAdPrice-subscriptionAmountPerMonth">/mes*</span>
                                </div>
                                <div class="mt-CardAdPrice-subscriptionLabel"><span class="mt-CardAdPrice-subscriptionLabel--highlight">IVA incluido</span></div>
                            </div>
                        </div>
                        <h2 class="mt-CardBasic-title mt-CardAd-title--oneLine" data-testid="card-ad-title">FORD Focus 1.5 Ecoblue 88kW Trend 5p.</h2>
                        <ul class="mt-CardAd-attr">
                            <li class="mt-CardAd-attrItem">Diesel</li>
                            <li class="mt-CardAd-attrItem">2021</li>
                            <li class="mt-CardAd-attrItem">Manual</li>
                        </ul>
                        <ul class="mt-CardAd-tags">
                            <div class="sui-AtomBadge sui-AtomBadge-size-medium sui-AtomBadge-type-gray sui-AtomBadge-design-soft"><span class="sui-AtomBadge-icon-text" title="Segunda mano">Segunda mano</span></div>
                        </ul>
                    </a></div>
            </div>
            <div class="mt-CardAd-fav">
                <div class="mt-CardAd-favIcon"><span class="sui-AtomIcon sui-AtomIcon--medium sui-AtomIcon--currentColor"><span><svg viewBox="0 0 24 24" xmlns="http://www.w3.org/2000/svg">
                                <path d="M6.607 3.057c1.93-.279 4.02.469 5.393 2.171 1.373-1.702 3.462-2.45 5.393-2.171a5.17 5.17 0 0 1 3.248 1.79C21.501 5.872 22 7.27 22 8.972c0 3.474-2.56 6.49-4.835 8.516a29.628 29.628 0 0 1-4.678 3.386 1 1 0 0 1-.974 0c-.14-.08-.279-.162-.417-.245a29.633 29.633 0 0 1-4.261-3.14C4.56 15.461 2 12.445 2 8.971c0-1.703.499-3.1 1.359-4.125a5.17 5.17 0 0 1 3.248-1.79Z"></path>
                            </svg></span></span></div>
            </div>
            <div class="mt-CardAd-footer">
                <div class="mt-CardAd-footerFinancingInfoContainer">* Permanencia: 12 meses · Kilómetros incluidos: 10.000 /año</div>
            </div>
        </div>
    </div>
    <div data-ad-id="58052455">
        <div class="mt-AnimationFadeOut mt-ListAds-item mt-CardAd mt-CardBasic">
            <div class="sui-AtomCard sui-AtomCard--responsive" role="button">
                <div class="sui-AtomCard-media">
                    <div class="mt-CardAd-mediaContainer"><a class="mt-CardAd-media " href="/renting/ford/focus/15_ecoblue_88kw_trend-diesel-2021-58052455-vsre" target="_self" title="FORD Focus 1.5 Ecoblue 88kW Trend 5p.">
                            <div class="sui-AtomImage is-loaded">
                                <figure class="sui-AtomImage-figure">
                                    <picture><img alt="FORD Focus 1.5 Ecoblue 88kW Trend 5p." class="mt-CardAd-mediaImage" decoding="auto" fetchpriority="auto" loading="eager" height="189" src="https://a.ccdn.es/cnet/2024/06/12/58052455/1925193041_g.jpg/252x189cut/" width="252" title="FORD Focus 1.5 Ecoblue 88kW Trend 5p."></picture>
                                </figure>
                            </div>
                        </a></div>
                </div>
                <div class="sui-AtomCard-info"><a href="/renting/ford/focus/15_ecoblue_88kw_trend-diesel-2021-58052455-vsre" class="mt-CardBasic-titleLink" title="FORD Focus 1.5 Ecoblue 88kW Trend 5p." target="_self">
                        <div class="mt-CardAdPrice">
                            <div class="mt-CardAdPrice-subscription mt-CardAdPrice-subscription--fullwidth"><span class="mt-CardAdPrice-subscriptionLabel">Cuota desde</span>
                                <div class="mt-CardAdPrice-subscriptionAmount">
                                    <div class="mt-TitleBasic-titleWrapper mt-TitleBasic-titleWrapper--currentColor mt-TitleBasic-titleWrapper--left">
                                        <h3 class="mt-TitleBasic-title mt-TitleBasic-title--s mt-TitleBasic-title--currentColor">366&nbsp;€</h3>
                                    </div><span class="mt-CardAdPrice-subscriptionAmountPerMonth">/mes*</span>
                                </div>
                                <div class="mt-CardAdPrice-subscriptionLabel"><span class="mt-CardAdPrice-subscriptionLabel--highlight">IVA incluido</span></div>
                            </div>
                        </div>
                        <h2 class="mt-CardBasic-title mt-CardAd-title--oneLine" data-testid="card-ad-title">FORD Focus 1.5 Ecoblue 88kW Trend 5p.</h2>
                        <ul class="mt-CardAd-attr">
                            <li class="mt-CardAd-attrItem">Diesel</li>
                            <li class="mt-CardAd-attrItem">2021</li>
                            <li class="mt-CardAd-attrItem">Manual</li>
                        </ul>
                        <ul class="mt-CardAd-tags">
                            <div class="sui-AtomBadge sui-AtomBadge-size-medium sui-AtomBadge-type-gray sui-AtomBadge-design-soft"><span class="sui-AtomBadge-icon-text" title="Segunda mano">Segunda mano</span></div>
                        </ul>
                    </a></div>
            </div>
            <div class="mt-CardAd-fav">
                <div class="mt-CardAd-favIcon"><span class="sui-AtomIcon sui-AtomIcon--medium sui-AtomIcon--currentColor"><span><svg viewBox="0 0 24 24" xmlns="http://www.w3.org/2000/svg">
                                <path d="M6.607 3.057c1.93-.279 4.02.469 5.393 2.171 1.373-1.702 3.462-2.45 5.393-2.171a5.17 5.17 0 0 1 3.248 1.79C21.501 5.872 22 7.27 22 8.972c0 3.474-2.56 6.49-4.835 8.516a29.628 29.628 0 0 1-4.678 3.386 1 1 0 0 1-.974 0c-.14-.08-.279-.162-.417-.245a29.633 29.633 0 0 1-4.261-3.14C4.56 15.461 2 12.445 2 8.971c0-1.703.499-3.1 1.359-4.125a5.17 5.17 0 0 1 3.248-1.79Z"></path>
                            </svg></span></span></div>
            </div>
            <div class="mt-CardAd-footer">
                <div class="mt-CardAd-footerFinancingInfoContainer">* Permanencia: 12 meses · Kilómetros incluidos: 10.000 /año</div>
            </div>
        </div>
    </div>
    <div class="mt-ListAds-item mt-ListAds-item--banner--desktop">
        <div id="ad-inline-2-wrapper" class="adit-saitama-SaitamaAd">
            <div id="ad-inline-2" data-google-query-id="COrl3euR_oYDFU9ypAQdUwQFBg">
                <div id="google_ads_iframe_/124564242/Cochesnet/Cochesnet-web_desktop/cn-wde-renting-list-inline_2_0__container__" style="border: 0pt none;"><iframe id="google_ads_iframe_/124564242/Cochesnet/Cochesnet-web_desktop/cn-wde-renting-list-inline_2_0" name="google_ads_iframe_/124564242/Cochesnet/Cochesnet-web_desktop/cn-wde-renting-list-inline_2_0" title="3rd party ad content" width="728" height="90" scrolling="no" marginwidth="0" marginheight="0" frameborder="0" aria-label="Advertisement" tabindex="0" allow="attribution-reporting" data-load-complete="true" data-google-container-id="3" style="border: 0px; vertical-align: bottom;"></iframe></div>
            </div>
        </div>
    </div>
    <div data-ad-id="57897752">
        <div class="mt-AnimationFadeOut mt-ListAds-item mt-CardAd mt-CardBasic">
            <div class="sui-AtomCard sui-AtomCard--responsive" role="button">
                <div class="sui-AtomCard-media">
                    <div class="mt-CardAd-mediaContainer"><a class="mt-CardAd-media " href="/renting/renault/clio/business_blue_dci_63_kw_85cv-diesel-2020-57897752-vsre" target="_self" title="RENAULT Clio Business Blue dCi 63 kW 85CV 5p.">
                            <div class="sui-AtomImage is-loaded">
                                <figure class="sui-AtomImage-figure">
                                    <picture><img alt="RENAULT Clio Business Blue dCi 63 kW 85CV 5p." class="mt-CardAd-mediaImage" decoding="auto" fetchpriority="auto" loading="eager" height="189" src="https://a.ccdn.es/cnet/2024/05/23/57897752/1920528631_g.jpg/252x189cut/" width="252" title="RENAULT Clio Business Blue dCi 63 kW 85CV 5p."></picture>
                                </figure>
                            </div>
                        </a></div>
                </div>
                <div class="sui-AtomCard-info"><a href="/renting/renault/clio/business_blue_dci_63_kw_85cv-diesel-2020-57897752-vsre" class="mt-CardBasic-titleLink" title="RENAULT Clio Business Blue dCi 63 kW 85CV 5p." target="_self">
                        <div class="mt-CardAdPrice">
                            <div class="mt-CardAdPrice-subscription mt-CardAdPrice-subscription--fullwidth"><span class="mt-CardAdPrice-subscriptionLabel">Cuota desde</span>
                                <div class="mt-CardAdPrice-subscriptionAmount">
                                    <div class="mt-TitleBasic-titleWrapper mt-TitleBasic-titleWrapper--currentColor mt-TitleBasic-titleWrapper--left">
                                        <h3 class="mt-TitleBasic-title mt-TitleBasic-title--s mt-TitleBasic-title--currentColor">329&nbsp;€</h3>
                                    </div><span class="mt-CardAdPrice-subscriptionAmountPerMonth">/mes*</span>
                                </div>
                                <div class="mt-CardAdPrice-subscriptionLabel"><span class="mt-CardAdPrice-subscriptionLabel--highlight">IVA incluido</span></div>
                            </div>
                        </div>
                        <h2 class="mt-CardBasic-title mt-CardAd-title--oneLine" data-testid="card-ad-title">RENAULT Clio Business Blue dCi 63 kW 85CV 5p.</h2>
                        <ul class="mt-CardAd-attr">
                            <li class="mt-CardAd-attrItem">Diesel</li>
                            <li class="mt-CardAd-attrItem">2021</li>
                            <li class="mt-CardAd-attrItem">Manual</li>
                        </ul>
                        <ul class="mt-CardAd-tags">
                            <div class="sui-AtomBadge sui-AtomBadge-size-medium sui-AtomBadge-type-gray sui-AtomBadge-design-soft"><span class="sui-AtomBadge-icon-text" title="Segunda mano">Segunda mano</span></div>
                        </ul>
                    </a></div>
            </div>
            <div class="mt-CardAd-fav">
                <div class="mt-CardAd-favIcon"><span class="sui-AtomIcon sui-AtomIcon--medium sui-AtomIcon--currentColor"><span><svg viewBox="0 0 24 24" xmlns="http://www.w3.org/2000/svg">
                                <path d="M6.607 3.057c1.93-.279 4.02.469 5.393 2.171 1.373-1.702 3.462-2.45 5.393-2.171a5.17 5.17 0 0 1 3.248 1.79C21.501 5.872 22 7.27 22 8.972c0 3.474-2.56 6.49-4.835 8.516a29.628 29.628 0 0 1-4.678 3.386 1 1 0 0 1-.974 0c-.14-.08-.279-.162-.417-.245a29.633 29.633 0 0 1-4.261-3.14C4.56 15.461 2 12.445 2 8.971c0-1.703.499-3.1 1.359-4.125a5.17 5.17 0 0 1 3.248-1.79Z"></path>
                            </svg></span></span></div>
            </div>
            <div class="mt-CardAd-footer">
                <div class="mt-CardAd-footerFinancingInfoContainer">* Permanencia: 12 meses · Kilómetros incluidos: 10.000 /año</div>
            </div>
        </div>
    </div>
    <div data-ad-id="57846460">
        <div class="mt-AnimationFadeOut mt-ListAds-item mt-CardAd mt-CardBasic">
            <div class="sui-AtomCard sui-AtomCard--responsive" role="button">
                <div class="sui-AtomCard-media">
                    <div class="mt-CardAd-mediaContainer"><a class="mt-CardAd-media " href="/renting/hyundai/i10/10_klass-gasolina-2023-57846460-vsre" target="_self" title="HYUNDAI i10 1.0 Klass 5p.">
                            <div class="sui-AtomImage is-loaded">
                                <figure class="sui-AtomImage-figure">
                                    <picture><img alt="HYUNDAI i10 1.0 Klass 5p." class="mt-CardAd-mediaImage" decoding="auto" fetchpriority="auto" loading="eager" height="189" src="https://a.ccdn.es/cnet/2024/02/15/57846460/1929210417_g.jpg/252x189cut/" width="252" title="HYUNDAI i10 1.0 Klass 5p."></picture>
                                </figure>
                            </div>
                        </a></div>
                </div>
                <div class="sui-AtomCard-info"><a href="/renting/hyundai/i10/10_klass-gasolina-2023-57846460-vsre" class="mt-CardBasic-titleLink" title="HYUNDAI i10 1.0 Klass 5p." target="_self">
                        <div class="mt-CardAdPrice">
                            <div class="mt-CardAdPrice-subscription mt-CardAdPrice-subscription--fullwidth">
                                <div class="mt-CardAdPrice-priceIndicator is-clickable">
                                    <div class="mt-CardAdPrice-priceIndicatorTitle"><span class="mt-CardAdPrice-cashLabel mt-CardAdPrice-cashLabel--noWrap">Precio justo</span></div>
                                    <div class="mt-CardAdPrice-priceIndicatorContainer mt-CardAdPrice-priceIndicatorContainer--small"><span class="mt-CardAdPrice-priceIndicatorContainerItem mt-CardAdPrice-priceIndicatorContainerItem--green"></span><span class="mt-CardAdPrice-priceIndicatorContainerItem mt-CardAdPrice-priceIndicatorContainerItem--green"></span><span class="mt-CardAdPrice-priceIndicatorContainerItem mt-CardAdPrice-priceIndicatorContainerItem--green"></span><span class="mt-CardAdPrice-priceIndicatorContainerItem mt-CardAdPrice-priceIndicatorContainerItem--default"></span><span class="mt-CardAdPrice-priceIndicatorContainerItem mt-CardAdPrice-priceIndicatorContainerItem--default"></span></div>
                                </div>
                                <div class="mt-CardAdPrice-subscriptionAmount">
                                    <div class="mt-TitleBasic-titleWrapper mt-TitleBasic-titleWrapper--currentColor mt-TitleBasic-titleWrapper--left">
                                        <h3 class="mt-TitleBasic-title mt-TitleBasic-title--s mt-TitleBasic-title--currentColor">308&nbsp;€</h3>
                                    </div><span class="mt-CardAdPrice-subscriptionAmountPerMonth">/mes*</span>
                                </div>
                                <div class="mt-CardAdPrice-subscriptionLabel"><span class="mt-CardAdPrice-subscriptionLabel--highlight">IVA incluido</span></div>
                            </div>
                        </div>
                        <h2 class="mt-CardBasic-title mt-CardAd-title--oneLine" data-testid="card-ad-title">HYUNDAI i10 1.0 Klass 5p.</h2>
                        <ul class="mt-CardAd-attr">
                            <li class="mt-CardAd-attrItem">Gasolina</li>
                            <li class="mt-CardAd-attrItem">2023</li>
                            <li class="mt-CardAd-attrItem">Manual</li>
                        </ul>
                        <ul class="mt-CardAd-tags">
                            <div class="sui-AtomBadge sui-AtomBadge-size-medium sui-AtomBadge-type-aquaWithoutHover sui-AtomBadge-design-soft"><span class="sui-AtomBadge-icon-text" title="En stock">En stock</span></div>
                            <div class="sui-AtomBadge sui-AtomBadge-size-medium sui-AtomBadge-type-gray sui-AtomBadge-design-soft"><span class="sui-AtomBadge-icon-text" title="Nuevo">Nuevo</span></div>
                        </ul>
                    </a></div>
            </div>
            <div class="mt-CardAd-fav">
                <div class="mt-CardAd-favIcon"><span class="sui-AtomIcon sui-AtomIcon--medium sui-AtomIcon--currentColor"><span><svg viewBox="0 0 24 24" xmlns="http://www.w3.org/2000/svg">
                                <path d="M6.607 3.057c1.93-.279 4.02.469 5.393 2.171 1.373-1.702 3.462-2.45 5.393-2.171a5.17 5.17 0 0 1 3.248 1.79C21.501 5.872 22 7.27 22 8.972c0 3.474-2.56 6.49-4.835 8.516a29.628 29.628 0 0 1-4.678 3.386 1 1 0 0 1-.974 0c-.14-.08-.279-.162-.417-.245a29.633 29.633 0 0 1-4.261-3.14C4.56 15.461 2 12.445 2 8.971c0-1.703.499-3.1 1.359-4.125a5.17 5.17 0 0 1 3.248-1.79Z"></path>
                            </svg></span></span></div>
            </div>
            <div class="mt-CardAd-footer">
                <div class="mt-CardAd-footerFinancingInfoContainer">* Permanencia: 48 meses · Kilómetros incluidos: 10.000 /año · También disponible: 36 meses</div>
            </div>
        </div>
    </div>
    <div data-ad-id="58155123">
        <div class="mt-AnimationFadeOut mt-ListAds-item mt-CardAd mt-CardBasic">
            <div class="sui-AtomCard sui-AtomCard--responsive" role="button">
                <div class="sui-AtomCard-media">
                    <div class="mt-CardAd-mediaContainer"><a class="mt-CardAd-media " href="/renting/opel/corsa/14_66kw_90cv_expression_pro-gasolina-2018-58155123-vsre" target="_self" title="OPEL Corsa 1.4 66kW 90CV Expression Pro 5p.">
                            <div class="sui-AtomImage is-loaded">
                                <figure class="sui-AtomImage-figure">
                                    <picture><img alt="OPEL Corsa 1.4 66kW 90CV Expression Pro 5p." class="mt-CardAd-mediaImage" decoding="auto" fetchpriority="auto" loading="eager" height="189" src="https://a.ccdn.es/cnet/2024/06/26/58155123/1929263192_g.jpg/252x189cut/" width="252" title="OPEL Corsa 1.4 66kW 90CV Expression Pro 5p."></picture>
                                </figure>
                            </div>
                        </a></div>
                </div>
                <div class="sui-AtomCard-info"><a href="/renting/opel/corsa/14_66kw_90cv_expression_pro-gasolina-2018-58155123-vsre" class="mt-CardBasic-titleLink" title="OPEL Corsa 1.4 66kW 90CV Expression Pro 5p." target="_self">
                        <div class="mt-CardAdPrice">
                            <div class="mt-CardAdPrice-subscription mt-CardAdPrice-subscription--fullwidth"><span class="mt-CardAdPrice-subscriptionLabel">Cuota desde</span>
                                <div class="mt-CardAdPrice-subscriptionAmount">
                                    <div class="mt-TitleBasic-titleWrapper mt-TitleBasic-titleWrapper--currentColor mt-TitleBasic-titleWrapper--left">
                                        <h3 class="mt-TitleBasic-title mt-TitleBasic-title--s mt-TitleBasic-title--currentColor">288&nbsp;€</h3>
                                    </div><span class="mt-CardAdPrice-subscriptionAmountPerMonth">/mes*</span>
                                </div>
                                <div class="mt-CardAdPrice-subscriptionLabel"><span class="mt-CardAdPrice-subscriptionLabel--highlight">IVA incluido</span></div>
                            </div>
                        </div>
                        <h2 class="mt-CardBasic-title mt-CardAd-title--oneLine" data-testid="card-ad-title">OPEL Corsa 1.4 66kW 90CV Expression Pro 5p.</h2>
                        <ul class="mt-CardAd-attr">
                            <li class="mt-CardAd-attrItem">Gasolina</li>
                            <li class="mt-CardAd-attrItem">2018</li>
                            <li class="mt-CardAd-attrItem">Manual</li>
                        </ul>
                        <ul class="mt-CardAd-tags">
                            <div class="sui-AtomBadge sui-AtomBadge-size-medium sui-AtomBadge-type-gray sui-AtomBadge-design-soft"><span class="sui-AtomBadge-icon-text" title="Segunda mano">Segunda mano</span></div>
                        </ul>
                    </a></div>
            </div>
            <div class="mt-CardAd-fav">
                <div class="mt-CardAd-favIcon"><span class="sui-AtomIcon sui-AtomIcon--medium sui-AtomIcon--currentColor"><span><svg viewBox="0 0 24 24" xmlns="http://www.w3.org/2000/svg">
                                <path d="M6.607 3.057c1.93-.279 4.02.469 5.393 2.171 1.373-1.702 3.462-2.45 5.393-2.171a5.17 5.17 0 0 1 3.248 1.79C21.501 5.872 22 7.27 22 8.972c0 3.474-2.56 6.49-4.835 8.516a29.628 29.628 0 0 1-4.678 3.386 1 1 0 0 1-.974 0c-.14-.08-.279-.162-.417-.245a29.633 29.633 0 0 1-4.261-3.14C4.56 15.461 2 12.445 2 8.971c0-1.703.499-3.1 1.359-4.125a5.17 5.17 0 0 1 3.248-1.79Z"></path>
                            </svg></span></span></div>
            </div>
            <div class="mt-CardAd-footer">
                <div class="mt-CardAd-footerFinancingInfoContainer">* Permanencia: 12 meses · Kilómetros incluidos: 10.000 /año</div>
            </div>
        </div>
    </div>
    <div data-ad-id="58172337">
        <div class="mt-AnimationFadeOut mt-ListAds-item mt-CardAd mt-CardBasic">
            <div class="sui-AtomCard sui-AtomCard--responsive" role="button">
                <div class="sui-AtomCard-media">
                    <div class="mt-CardAd-mediaContainer"><a class="mt-CardAd-media " href="/renting/opel/corsa/14_66kw_90cv_expression_pro-gasolina-2018-58172337-vsre" target="_self" title="OPEL Corsa 1.4 66kW 90CV Expression Pro 5p.">
                            <div class="sui-AtomImage is-loaded">
                                <figure class="sui-AtomImage-figure">
                                    <picture><img alt="OPEL Corsa 1.4 66kW 90CV Expression Pro 5p." class="mt-CardAd-mediaImage" decoding="auto" fetchpriority="auto" loading="eager" height="189" src="https://a.ccdn.es/cnet/2024/06/28/58172337/1930027668_g.jpg/252x189cut/" width="252" title="OPEL Corsa 1.4 66kW 90CV Expression Pro 5p."></picture>
                                </figure>
                            </div>
                        </a></div>
                </div>
                <div class="sui-AtomCard-info"><a href="/renting/opel/corsa/14_66kw_90cv_expression_pro-gasolina-2018-58172337-vsre" class="mt-CardBasic-titleLink" title="OPEL Corsa 1.4 66kW 90CV Expression Pro 5p." target="_self">
                        <div class="mt-CardAdPrice">
                            <div class="mt-CardAdPrice-subscription mt-CardAdPrice-subscription--fullwidth"><span class="mt-CardAdPrice-subscriptionLabel">Cuota desde</span>
                                <div class="mt-CardAdPrice-subscriptionAmount">
                                    <div class="mt-TitleBasic-titleWrapper mt-TitleBasic-titleWrapper--currentColor mt-TitleBasic-titleWrapper--left">
                                        <h3 class="mt-TitleBasic-title mt-TitleBasic-title--s mt-TitleBasic-title--currentColor">288&nbsp;€</h3>
                                    </div><span class="mt-CardAdPrice-subscriptionAmountPerMonth">/mes*</span>
                                </div>
                                <div class="mt-CardAdPrice-subscriptionLabel"><span class="mt-CardAdPrice-subscriptionLabel--highlight">IVA incluido</span></div>
                            </div>
                        </div>
                        <h2 class="mt-CardBasic-title mt-CardAd-title--oneLine" data-testid="card-ad-title">OPEL Corsa 1.4 66kW 90CV Expression Pro 5p.</h2>
                        <ul class="mt-CardAd-attr">
                            <li class="mt-CardAd-attrItem">Gasolina</li>
                            <li class="mt-CardAd-attrItem">2018</li>
                            <li class="mt-CardAd-attrItem">Manual</li>
                        </ul>
                        <ul class="mt-CardAd-tags">
                            <div class="sui-AtomBadge sui-AtomBadge-size-medium sui-AtomBadge-type-gray sui-AtomBadge-design-soft"><span class="sui-AtomBadge-icon-text" title="Segunda mano">Segunda mano</span></div>
                        </ul>
                    </a></div>
            </div>
            <div class="mt-CardAd-fav">
                <div class="mt-CardAd-favIcon"><span class="sui-AtomIcon sui-AtomIcon--medium sui-AtomIcon--currentColor"><span><svg viewBox="0 0 24 24" xmlns="http://www.w3.org/2000/svg">
                                <path d="M6.607 3.057c1.93-.279 4.02.469 5.393 2.171 1.373-1.702 3.462-2.45 5.393-2.171a5.17 5.17 0 0 1 3.248 1.79C21.501 5.872 22 7.27 22 8.972c0 3.474-2.56 6.49-4.835 8.516a29.628 29.628 0 0 1-4.678 3.386 1 1 0 0 1-.974 0c-.14-.08-.279-.162-.417-.245a29.633 29.633 0 0 1-4.261-3.14C4.56 15.461 2 12.445 2 8.971c0-1.703.499-3.1 1.359-4.125a5.17 5.17 0 0 1 3.248-1.79Z"></path>
                            </svg></span></span></div>
            </div>
            <div class="mt-CardAd-footer">
                <div class="mt-CardAd-footerFinancingInfoContainer">* Permanencia: 12 meses · Kilómetros incluidos: 10.000 /año</div>
            </div>
        </div>
    </div>
    <div data-ad-id="57897716">
        <div class="mt-AnimationFadeOut mt-ListAds-item mt-CardAd mt-CardBasic">
            <div class="sui-AtomCard sui-AtomCard--responsive" role="button">
                <div class="sui-AtomCard-media">
                    <div class="mt-CardAd-mediaContainer"><a class="mt-CardAd-media " href="/renting/renault/clio/business_sce_49_kw_67cv-gasolina-2021-57897716-vsre" target="_self" title="RENAULT Clio Business SCe 49 kW 67CV 5p.">
                            <div class="sui-AtomImage is-loaded">
                                <figure class="sui-AtomImage-figure">
                                    <picture><img alt="RENAULT Clio Business SCe 49 kW 67CV 5p." class="mt-CardAd-mediaImage" decoding="auto" fetchpriority="auto" loading="eager" height="189" src="https://a.ccdn.es/cnet/2024/05/23/57897716/1920530874_g.jpg/252x189cut/" width="252" title="RENAULT Clio Business SCe 49 kW 67CV 5p."></picture>
                                </figure>
                            </div>
                        </a></div>
                </div>
                <div class="sui-AtomCard-info"><a href="/renting/renault/clio/business_sce_49_kw_67cv-gasolina-2021-57897716-vsre" class="mt-CardBasic-titleLink" title="RENAULT Clio Business SCe 49 kW 67CV 5p." target="_self">
                        <div class="mt-CardAdPrice">
                            <div class="mt-CardAdPrice-subscription mt-CardAdPrice-subscription--fullwidth"><span class="mt-CardAdPrice-subscriptionLabel">Cuota desde</span>
                                <div class="mt-CardAdPrice-subscriptionAmount">
                                    <div class="mt-TitleBasic-titleWrapper mt-TitleBasic-titleWrapper--currentColor mt-TitleBasic-titleWrapper--left">
                                        <h3 class="mt-TitleBasic-title mt-TitleBasic-title--s mt-TitleBasic-title--currentColor">322&nbsp;€</h3>
                                    </div><span class="mt-CardAdPrice-subscriptionAmountPerMonth">/mes*</span>
                                </div>
                                <div class="mt-CardAdPrice-subscriptionLabel"><span class="mt-CardAdPrice-subscriptionLabel--highlight">IVA incluido</span></div>
                            </div>
                        </div>
                        <h2 class="mt-CardBasic-title mt-CardAd-title--oneLine" data-testid="card-ad-title">RENAULT Clio Business SCe 49 kW 67CV 5p.</h2>
                        <ul class="mt-CardAd-attr">
                            <li class="mt-CardAd-attrItem">Gasolina</li>
                            <li class="mt-CardAd-attrItem">2021</li>
                            <li class="mt-CardAd-attrItem">Manual</li>
                        </ul>
                        <ul class="mt-CardAd-tags">
                            <div class="sui-AtomBadge sui-AtomBadge-size-medium sui-AtomBadge-type-gray sui-AtomBadge-design-soft"><span class="sui-AtomBadge-icon-text" title="Segunda mano">Segunda mano</span></div>
                        </ul>
                    </a></div>
            </div>
            <div class="mt-CardAd-fav">
                <div class="mt-CardAd-favIcon"><span class="sui-AtomIcon sui-AtomIcon--medium sui-AtomIcon--currentColor"><span><svg viewBox="0 0 24 24" xmlns="http://www.w3.org/2000/svg">
                                <path d="M6.607 3.057c1.93-.279 4.02.469 5.393 2.171 1.373-1.702 3.462-2.45 5.393-2.171a5.17 5.17 0 0 1 3.248 1.79C21.501 5.872 22 7.27 22 8.972c0 3.474-2.56 6.49-4.835 8.516a29.628 29.628 0 0 1-4.678 3.386 1 1 0 0 1-.974 0c-.14-.08-.279-.162-.417-.245a29.633 29.633 0 0 1-4.261-3.14C4.56 15.461 2 12.445 2 8.971c0-1.703.499-3.1 1.359-4.125a5.17 5.17 0 0 1 3.248-1.79Z"></path>
                            </svg></span></span></div>
            </div>
            <div class="mt-CardAd-footer">
                <div class="mt-CardAd-footerFinancingInfoContainer">* Permanencia: 12 meses · Kilómetros incluidos: 10.000 /año</div>
            </div>
        </div>
    </div>
    <div data-ad-id="58155276">
        <div class="mt-AnimationFadeOut mt-ListAds-item mt-CardAd mt-CardBasic">
            <div class="sui-AtomCard sui-AtomCard--responsive" role="button">
                <div class="sui-AtomCard-media">
                    <div class="mt-CardAd-mediaContainer"><a class="mt-CardAd-media " href="/renting/renault/clio/business_sce_49_kw_67cv-gasolina-2021-58155276-vsre" target="_self" title="RENAULT Clio Business SCe 49 kW 67CV 5p.">
                            <div class="sui-AtomImage is-loaded">
                                <figure class="sui-AtomImage-figure">
                                    <picture><img alt="RENAULT Clio Business SCe 49 kW 67CV 5p." class="mt-CardAd-mediaImage" decoding="auto" fetchpriority="auto" loading="eager" height="189" src="https://a.ccdn.es/cnet/2024/06/26/58155276/1929266927_g.jpg/252x189cut/" width="252" title="RENAULT Clio Business SCe 49 kW 67CV 5p."></picture>
                                </figure>
                            </div>
                        </a></div>
                </div>
                <div class="sui-AtomCard-info"><a href="/renting/renault/clio/business_sce_49_kw_67cv-gasolina-2021-58155276-vsre" class="mt-CardBasic-titleLink" title="RENAULT Clio Business SCe 49 kW 67CV 5p." target="_self">
                        <div class="mt-CardAdPrice">
                            <div class="mt-CardAdPrice-subscription mt-CardAdPrice-subscription--fullwidth"><span class="mt-CardAdPrice-subscriptionLabel">Cuota desde</span>
                                <div class="mt-CardAdPrice-subscriptionAmount">
                                    <div class="mt-TitleBasic-titleWrapper mt-TitleBasic-titleWrapper--currentColor mt-TitleBasic-titleWrapper--left">
                                        <h3 class="mt-TitleBasic-title mt-TitleBasic-title--s mt-TitleBasic-title--currentColor">322&nbsp;€</h3>
                                    </div><span class="mt-CardAdPrice-subscriptionAmountPerMonth">/mes*</span>
                                </div>
                                <div class="mt-CardAdPrice-subscriptionLabel"><span class="mt-CardAdPrice-subscriptionLabel--highlight">IVA incluido</span></div>
                            </div>
                        </div>
                        <h2 class="mt-CardBasic-title mt-CardAd-title--oneLine" data-testid="card-ad-title">RENAULT Clio Business SCe 49 kW 67CV 5p.</h2>
                        <ul class="mt-CardAd-attr">
                            <li class="mt-CardAd-attrItem">Gasolina</li>
                            <li class="mt-CardAd-attrItem">2021</li>
                            <li class="mt-CardAd-attrItem">Manual</li>
                        </ul>
                        <ul class="mt-CardAd-tags">
                            <div class="sui-AtomBadge sui-AtomBadge-size-medium sui-AtomBadge-type-gray sui-AtomBadge-design-soft"><span class="sui-AtomBadge-icon-text" title="Segunda mano">Segunda mano</span></div>
                        </ul>
                    </a></div>
            </div>
            <div class="mt-CardAd-fav">
                <div class="mt-CardAd-favIcon"><span class="sui-AtomIcon sui-AtomIcon--medium sui-AtomIcon--currentColor"><span><svg viewBox="0 0 24 24" xmlns="http://www.w3.org/2000/svg">
                                <path d="M6.607 3.057c1.93-.279 4.02.469 5.393 2.171 1.373-1.702 3.462-2.45 5.393-2.171a5.17 5.17 0 0 1 3.248 1.79C21.501 5.872 22 7.27 22 8.972c0 3.474-2.56 6.49-4.835 8.516a29.628 29.628 0 0 1-4.678 3.386 1 1 0 0 1-.974 0c-.14-.08-.279-.162-.417-.245a29.633 29.633 0 0 1-4.261-3.14C4.56 15.461 2 12.445 2 8.971c0-1.703.499-3.1 1.359-4.125a5.17 5.17 0 0 1 3.248-1.79Z"></path>
                            </svg></span></span></div>
            </div>
            <div class="mt-CardAd-footer">
                <div class="mt-CardAd-footerFinancingInfoContainer">* Permanencia: 12 meses · Kilómetros incluidos: 10.000 /año</div>
            </div>
        </div>
    </div>
    <div data-ad-id="58172167">
        <div class="mt-AnimationFadeOut mt-ListAds-item mt-CardAd mt-CardBasic">
            <div class="sui-AtomCard sui-AtomCard--responsive" role="button">
                <div class="sui-AtomCard-media">
                    <div class="mt-CardAd-mediaContainer"><a class="mt-CardAd-media " href="/renting/citroen/c3/puretech_60kw_82cv_feel-gasolina-2019-58172167-vsre" target="_self" title="CITROEN C3 PureTech 60KW 82CV FEEL 5p.">
                            <div class="sui-AtomImage is-loaded">
                                <figure class="sui-AtomImage-figure">
                                    <picture><img alt="CITROEN C3 PureTech 60KW 82CV FEEL 5p." class="mt-CardAd-mediaImage" decoding="auto" fetchpriority="auto" loading="eager" height="189" src="https://a.ccdn.es/cnet/2024/06/28/58172167/1930024561_g.jpg/252x189cut/" width="252" title="CITROEN C3 PureTech 60KW 82CV FEEL 5p."></picture>
                                </figure>
                            </div>
                        </a></div>
                </div>
                <div class="sui-AtomCard-info"><a href="/renting/citroen/c3/puretech_60kw_82cv_feel-gasolina-2019-58172167-vsre" class="mt-CardBasic-titleLink" title="CITROEN C3 PureTech 60KW 82CV FEEL 5p." target="_self">
                        <div class="mt-CardAdPrice">
                            <div class="mt-CardAdPrice-subscription mt-CardAdPrice-subscription--fullwidth"><span class="mt-CardAdPrice-subscriptionLabel">Cuota desde</span>
                                <div class="mt-CardAdPrice-subscriptionAmount">
                                    <div class="mt-TitleBasic-titleWrapper mt-TitleBasic-titleWrapper--currentColor mt-TitleBasic-titleWrapper--left">
                                        <h3 class="mt-TitleBasic-title mt-TitleBasic-title--s mt-TitleBasic-title--currentColor">296&nbsp;€</h3>
                                    </div><span class="mt-CardAdPrice-subscriptionAmountPerMonth">/mes*</span>
                                </div>
                                <div class="mt-CardAdPrice-subscriptionLabel"><span class="mt-CardAdPrice-subscriptionLabel--highlight">IVA incluido</span></div>
                            </div>
                        </div>
                        <h2 class="mt-CardBasic-title mt-CardAd-title--oneLine" data-testid="card-ad-title">CITROEN C3 PureTech 60KW 82CV FEEL 5p.</h2>
                        <ul class="mt-CardAd-attr">
                            <li class="mt-CardAd-attrItem">Gasolina</li>
                            <li class="mt-CardAd-attrItem">2018</li>
                            <li class="mt-CardAd-attrItem">Manual</li>
                        </ul>
                        <ul class="mt-CardAd-tags">
                            <div class="sui-AtomBadge sui-AtomBadge-size-medium sui-AtomBadge-type-gray sui-AtomBadge-design-soft"><span class="sui-AtomBadge-icon-text" title="Segunda mano">Segunda mano</span></div>
                        </ul>
                    </a></div>
            </div>
            <div class="mt-CardAd-fav">
                <div class="mt-CardAd-favIcon"><span class="sui-AtomIcon sui-AtomIcon--medium sui-AtomIcon--currentColor"><span><svg viewBox="0 0 24 24" xmlns="http://www.w3.org/2000/svg">
                                <path d="M6.607 3.057c1.93-.279 4.02.469 5.393 2.171 1.373-1.702 3.462-2.45 5.393-2.171a5.17 5.17 0 0 1 3.248 1.79C21.501 5.872 22 7.27 22 8.972c0 3.474-2.56 6.49-4.835 8.516a29.628 29.628 0 0 1-4.678 3.386 1 1 0 0 1-.974 0c-.14-.08-.279-.162-.417-.245a29.633 29.633 0 0 1-4.261-3.14C4.56 15.461 2 12.445 2 8.971c0-1.703.499-3.1 1.359-4.125a5.17 5.17 0 0 1 3.248-1.79Z"></path>
                            </svg></span></span></div>
            </div>
            <div class="mt-CardAd-footer">
                <div class="mt-CardAd-footerFinancingInfoContainer">* Permanencia: 12 meses · Kilómetros incluidos: 10.000 /año</div>
            </div>
        </div>
    </div>
    <div data-ad-id="57920076">
        <div class="mt-AnimationFadeOut mt-ListAds-item mt-CardAd mt-CardBasic">
            <div class="sui-AtomCard sui-AtomCard--responsive" role="button">
                <div class="sui-AtomCard-media">
                    <div class="mt-CardAd-mediaContainer"><a class="mt-CardAd-media " href="/renting/ford/fiesta/11_tivct_55kw_75cv_trend_5p-gasolina-2021-57920076-vsre" target="_self" title="FORD Fiesta 1.1 TiVCT 55kW 75CV Trend 5p 5p.">
                            <div class="sui-AtomImage is-loaded">
                                <figure class="sui-AtomImage-figure">
                                    <picture><img alt="FORD Fiesta 1.1 TiVCT 55kW 75CV Trend 5p 5p." class="mt-CardAd-mediaImage" decoding="auto" fetchpriority="auto" loading="eager" height="189" src="https://a.ccdn.es/cnet/2024/05/27/57920076/1920531807_g.jpg/252x189cut/" width="252" title="FORD Fiesta 1.1 TiVCT 55kW 75CV Trend 5p 5p."></picture>
                                </figure>
                            </div>
                        </a></div>
                </div>
                <div class="sui-AtomCard-info"><a href="/renting/ford/fiesta/11_tivct_55kw_75cv_trend_5p-gasolina-2021-57920076-vsre" class="mt-CardBasic-titleLink" title="FORD Fiesta 1.1 TiVCT 55kW 75CV Trend 5p 5p." target="_self">
                        <div class="mt-CardAdPrice">
                            <div class="mt-CardAdPrice-subscription mt-CardAdPrice-subscription--fullwidth"><span class="mt-CardAdPrice-subscriptionLabel">Cuota desde</span>
                                <div class="mt-CardAdPrice-subscriptionAmount">
                                    <div class="mt-TitleBasic-titleWrapper mt-TitleBasic-titleWrapper--currentColor mt-TitleBasic-titleWrapper--left">
                                        <h3 class="mt-TitleBasic-title mt-TitleBasic-title--s mt-TitleBasic-title--currentColor">379&nbsp;€</h3>
                                    </div><span class="mt-CardAdPrice-subscriptionAmountPerMonth">/mes*</span>
                                </div>
                                <div class="mt-CardAdPrice-subscriptionLabel"><span class="mt-CardAdPrice-subscriptionLabel--highlight">IVA incluido</span></div>
                            </div>
                        </div>
                        <h2 class="mt-CardBasic-title mt-CardAd-title--oneLine" data-testid="card-ad-title">FORD Fiesta 1.1 TiVCT 55kW 75CV Trend 5p 5p.</h2>
                        <ul class="mt-CardAd-attr">
                            <li class="mt-CardAd-attrItem">Gasolina</li>
                            <li class="mt-CardAd-attrItem">2021</li>
                            <li class="mt-CardAd-attrItem">Manual</li>
                        </ul>
                        <ul class="mt-CardAd-tags">
                            <div class="sui-AtomBadge sui-AtomBadge-size-medium sui-AtomBadge-type-gray sui-AtomBadge-design-soft"><span class="sui-AtomBadge-icon-text" title="Segunda mano">Segunda mano</span></div>
                        </ul>
                    </a></div>
            </div>
            <div class="mt-CardAd-fav">
                <div class="mt-CardAd-favIcon"><span class="sui-AtomIcon sui-AtomIcon--medium sui-AtomIcon--currentColor"><span><svg viewBox="0 0 24 24" xmlns="http://www.w3.org/2000/svg">
                                <path d="M6.607 3.057c1.93-.279 4.02.469 5.393 2.171 1.373-1.702 3.462-2.45 5.393-2.171a5.17 5.17 0 0 1 3.248 1.79C21.501 5.872 22 7.27 22 8.972c0 3.474-2.56 6.49-4.835 8.516a29.628 29.628 0 0 1-4.678 3.386 1 1 0 0 1-.974 0c-.14-.08-.279-.162-.417-.245a29.633 29.633 0 0 1-4.261-3.14C4.56 15.461 2 12.445 2 8.971c0-1.703.499-3.1 1.359-4.125a5.17 5.17 0 0 1 3.248-1.79Z"></path>
                            </svg></span></span></div>
            </div>
            <div class="mt-CardAd-footer">
                <div class="mt-CardAd-footerFinancingInfoContainer">* Permanencia: 12 meses · Kilómetros incluidos: 10.000 /año</div>
            </div>
        </div>
    </div>
    <div data-ad-id="55710885">
        <div class="mt-AnimationFadeOut mt-ListAds-item mt-CardAd mt-CardBasic">
            <div class="sui-AtomCard sui-AtomCard--responsive" role="button">
                <div class="sui-AtomCard-media">
                    <div class="mt-CardAd-mediaContainer"><a class="mt-CardAd-media " href="/renting/skoda/scala/10_tsi_70_kw_95_cv_ambition-gasolina-2023-55710885-vsre" target="_self" title="SKODA Scala 1.0 TSI 70 KW 95 CV Ambition 5p.">
                            <div class="sui-AtomImage is-loaded">
                                <figure class="sui-AtomImage-figure">
                                    <picture><img alt="SKODA Scala 1.0 TSI 70 KW 95 CV Ambition 5p." class="mt-CardAd-mediaImage" decoding="auto" fetchpriority="auto" loading="eager" height="189" src="https://a.ccdn.es/cnet/2023/07/31/55710885/1899512407_g.jpg/252x189cut/" width="252" title="SKODA Scala 1.0 TSI 70 KW 95 CV Ambition 5p."></picture>
                                </figure>
                            </div>
                        </a></div>
                </div>
                <div class="sui-AtomCard-info"><a href="/renting/skoda/scala/10_tsi_70_kw_95_cv_ambition-gasolina-2023-55710885-vsre" class="mt-CardBasic-titleLink" title="SKODA Scala 1.0 TSI 70 KW 95 CV Ambition 5p." target="_self">
                        <div class="mt-CardAdPrice">
                            <div class="mt-CardAdPrice-subscription mt-CardAdPrice-subscription--fullwidth">
                                <div class="mt-CardAdPrice-priceIndicator is-clickable">
                                    <div class="mt-CardAdPrice-priceIndicatorTitle"><span class="mt-CardAdPrice-cashLabel mt-CardAdPrice-cashLabel--noWrap">Buen precio</span></div>
                                    <div class="mt-CardAdPrice-priceIndicatorContainer mt-CardAdPrice-priceIndicatorContainer--small"><span class="mt-CardAdPrice-priceIndicatorContainerItem mt-CardAdPrice-priceIndicatorContainerItem--green"></span><span class="mt-CardAdPrice-priceIndicatorContainerItem mt-CardAdPrice-priceIndicatorContainerItem--green"></span><span class="mt-CardAdPrice-priceIndicatorContainerItem mt-CardAdPrice-priceIndicatorContainerItem--green"></span><span class="mt-CardAdPrice-priceIndicatorContainerItem mt-CardAdPrice-priceIndicatorContainerItem--green"></span><span class="mt-CardAdPrice-priceIndicatorContainerItem mt-CardAdPrice-priceIndicatorContainerItem--default"></span></div>
                                </div>
                                <div class="mt-CardAdPrice-subscriptionAmount">
                                    <div class="mt-TitleBasic-titleWrapper mt-TitleBasic-titleWrapper--currentColor mt-TitleBasic-titleWrapper--left">
                                        <h3 class="mt-TitleBasic-title mt-TitleBasic-title--s mt-TitleBasic-title--currentColor">370&nbsp;€</h3>
                                    </div><span class="mt-CardAdPrice-subscriptionAmountPerMonth">/mes*</span>
                                </div>
                                <div class="mt-CardAdPrice-subscriptionLabel"><span class="mt-CardAdPrice-subscriptionLabel--highlight">IVA incluido</span></div>
                            </div>
                        </div>
                        <h2 class="mt-CardBasic-title mt-CardAd-title--oneLine" data-testid="card-ad-title">SKODA Scala 1.0 TSI 70 KW 95 CV Ambition 5p.</h2>
                        <ul class="mt-CardAd-attr">
                            <li class="mt-CardAd-attrItem">Gasolina</li>
                            <li class="mt-CardAd-attrItem">2023</li>
                            <li class="mt-CardAd-attrItem">Manual</li>
                        </ul>
                        <ul class="mt-CardAd-tags">
                            <div class="sui-AtomBadge sui-AtomBadge-size-medium sui-AtomBadge-type-gray sui-AtomBadge-design-soft"><span class="sui-AtomBadge-icon-text" title="Nuevo">Nuevo</span></div>
                        </ul>
                    </a></div>
            </div>
            <div class="mt-CardAd-fav">
                <div class="mt-CardAd-favIcon"><span class="sui-AtomIcon sui-AtomIcon--medium sui-AtomIcon--currentColor"><span><svg viewBox="0 0 24 24" xmlns="http://www.w3.org/2000/svg">
                                <path d="M6.607 3.057c1.93-.279 4.02.469 5.393 2.171 1.373-1.702 3.462-2.45 5.393-2.171a5.17 5.17 0 0 1 3.248 1.79C21.501 5.872 22 7.27 22 8.972c0 3.474-2.56 6.49-4.835 8.516a29.628 29.628 0 0 1-4.678 3.386 1 1 0 0 1-.974 0c-.14-.08-.279-.162-.417-.245a29.633 29.633 0 0 1-4.261-3.14C4.56 15.461 2 12.445 2 8.971c0-1.703.499-3.1 1.359-4.125a5.17 5.17 0 0 1 3.248-1.79Z"></path>
                            </svg></span></span></div>
            </div>
            <div class="mt-CardAd-footer">
                <div class="mt-CardAd-footerFinancingInfoContainer">* Permanencia: 60 meses · Kilómetros incluidos: 10.000 /año · También disponible: 36 y 48 meses</div>
            </div>
        </div>
    </div>
    <div data-ad-id="57972480">
        <div class="mt-AnimationFadeOut mt-ListAds-item mt-CardAd mt-CardBasic">
            <div class="sui-AtomCard sui-AtomCard--responsive" role="button">
                <div class="sui-AtomCard-media">
                    <div class="mt-CardAd-mediaContainer"><a class="mt-CardAd-media " href="/renting/seat/ibiza/10_tgi_66kw_90cv_style--2021-57972480-vsre" target="_self" title="SEAT Ibiza 1.0 TGI 66kW 90CV Style 5p.">
                            <div class="sui-AtomImage is-loaded">
                                <figure class="sui-AtomImage-figure">
                                    <picture><img alt="SEAT Ibiza 1.0 TGI 66kW 90CV Style 5p." class="mt-CardAd-mediaImage" decoding="auto" fetchpriority="auto" loading="eager" height="189" src="https://a.ccdn.es/cnet/2024/06/03/57972480/1922043159_g.jpg/252x189cut/" width="252" title="SEAT Ibiza 1.0 TGI 66kW 90CV Style 5p."></picture>
                                </figure>
                            </div>
                        </a></div>
                </div>
                <div class="sui-AtomCard-info"><a href="/renting/seat/ibiza/10_tgi_66kw_90cv_style--2021-57972480-vsre" class="mt-CardBasic-titleLink" title="SEAT Ibiza 1.0 TGI 66kW 90CV Style 5p." target="_self">
                        <div class="mt-CardAdPrice">
                            <div class="mt-CardAdPrice-subscription mt-CardAdPrice-subscription--fullwidth"><span class="mt-CardAdPrice-subscriptionLabel">Cuota desde</span>
                                <div class="mt-CardAdPrice-subscriptionAmount">
                                    <div class="mt-TitleBasic-titleWrapper mt-TitleBasic-titleWrapper--currentColor mt-TitleBasic-titleWrapper--left">
                                        <h3 class="mt-TitleBasic-title mt-TitleBasic-title--s mt-TitleBasic-title--currentColor">394&nbsp;€</h3>
                                    </div><span class="mt-CardAdPrice-subscriptionAmountPerMonth">/mes*</span>
                                </div>
                                <div class="mt-CardAdPrice-subscriptionLabel"><span class="mt-CardAdPrice-subscriptionLabel--highlight">IVA incluido</span></div>
                            </div>
                        </div>
                        <h2 class="mt-CardBasic-title mt-CardAd-title--oneLine" data-testid="card-ad-title">SEAT Ibiza 1.0 TGI 66kW 90CV Style 5p.</h2>
                        <ul class="mt-CardAd-attr">
                            <li class="mt-CardAd-attrItem">Gas natural (CNG)</li>
                            <li class="mt-CardAd-attrItem">2021</li>
                            <li class="mt-CardAd-attrItem">Manual</li>
                        </ul>
                        <ul class="mt-CardAd-tags">
                            <div class="sui-AtomBadge sui-AtomBadge-size-medium sui-AtomBadge-type-gray sui-AtomBadge-design-soft"><span class="sui-AtomBadge-icon-text" title="Segunda mano">Segunda mano</span></div>
                        </ul>
                    </a></div>
            </div>
            <div class="mt-CardAd-fav">
                <div class="mt-CardAd-favIcon"><span class="sui-AtomIcon sui-AtomIcon--medium sui-AtomIcon--currentColor"><span><svg viewBox="0 0 24 24" xmlns="http://www.w3.org/2000/svg">
                                <path d="M6.607 3.057c1.93-.279 4.02.469 5.393 2.171 1.373-1.702 3.462-2.45 5.393-2.171a5.17 5.17 0 0 1 3.248 1.79C21.501 5.872 22 7.27 22 8.972c0 3.474-2.56 6.49-4.835 8.516a29.628 29.628 0 0 1-4.678 3.386 1 1 0 0 1-.974 0c-.14-.08-.279-.162-.417-.245a29.633 29.633 0 0 1-4.261-3.14C4.56 15.461 2 12.445 2 8.971c0-1.703.499-3.1 1.359-4.125a5.17 5.17 0 0 1 3.248-1.79Z"></path>
                            </svg></span></span></div>
            </div>
            <div class="mt-CardAd-footer">
                <div class="mt-CardAd-footerFinancingInfoContainer">* Permanencia: 12 meses · Kilómetros incluidos: 10.000 /año</div>
            </div>
        </div>
    </div>
    <div data-ad-id="58155006">
        <div class="mt-AnimationFadeOut mt-ListAds-item mt-CardAd mt-CardBasic">
            <div class="sui-AtomCard sui-AtomCard--responsive" role="button">
                <div class="sui-AtomCard-media">
                    <div class="mt-CardAd-mediaContainer"><a class="mt-CardAd-media " href="/renting/seat/ibiza/10_tgi_66kw_90cv_style--2021-58155006-vsre" target="_self" title="SEAT Ibiza 1.0 TGI 66kW 90CV Style 5p.">
                            <div class="sui-AtomImage is-loaded">
                                <figure class="sui-AtomImage-figure">
                                    <picture><img alt="SEAT Ibiza 1.0 TGI 66kW 90CV Style 5p." class="mt-CardAd-mediaImage" decoding="auto" fetchpriority="auto" loading="eager" height="189" src="https://a.ccdn.es/cnet/2024/06/26/58155006/1929260808_g.jpg/252x189cut/" width="252" title="SEAT Ibiza 1.0 TGI 66kW 90CV Style 5p."></picture>
                                </figure>
                            </div>
                        </a></div>
                </div>
                <div class="sui-AtomCard-info"><a href="/renting/seat/ibiza/10_tgi_66kw_90cv_style--2021-58155006-vsre" class="mt-CardBasic-titleLink" title="SEAT Ibiza 1.0 TGI 66kW 90CV Style 5p." target="_self">
                        <div class="mt-CardAdPrice">
                            <div class="mt-CardAdPrice-subscription mt-CardAdPrice-subscription--fullwidth"><span class="mt-CardAdPrice-subscriptionLabel">Cuota desde</span>
                                <div class="mt-CardAdPrice-subscriptionAmount">
                                    <div class="mt-TitleBasic-titleWrapper mt-TitleBasic-titleWrapper--currentColor mt-TitleBasic-titleWrapper--left">
                                        <h3 class="mt-TitleBasic-title mt-TitleBasic-title--s mt-TitleBasic-title--currentColor">394&nbsp;€</h3>
                                    </div><span class="mt-CardAdPrice-subscriptionAmountPerMonth">/mes*</span>
                                </div>
                                <div class="mt-CardAdPrice-subscriptionLabel"><span class="mt-CardAdPrice-subscriptionLabel--highlight">IVA incluido</span></div>
                            </div>
                        </div>
                        <h2 class="mt-CardBasic-title mt-CardAd-title--oneLine" data-testid="card-ad-title">SEAT Ibiza 1.0 TGI 66kW 90CV Style 5p.</h2>
                        <ul class="mt-CardAd-attr">
                            <li class="mt-CardAd-attrItem">Gas natural (CNG)</li>
                            <li class="mt-CardAd-attrItem">2021</li>
                            <li class="mt-CardAd-attrItem">Manual</li>
                        </ul>
                        <ul class="mt-CardAd-tags">
                            <div class="sui-AtomBadge sui-AtomBadge-size-medium sui-AtomBadge-type-gray sui-AtomBadge-design-soft"><span class="sui-AtomBadge-icon-text" title="Segunda mano">Segunda mano</span></div>
                        </ul>
                    </a></div>
            </div>
            <div class="mt-CardAd-fav">
                <div class="mt-CardAd-favIcon"><span class="sui-AtomIcon sui-AtomIcon--medium sui-AtomIcon--currentColor"><span><svg viewBox="0 0 24 24" xmlns="http://www.w3.org/2000/svg">
                                <path d="M6.607 3.057c1.93-.279 4.02.469 5.393 2.171 1.373-1.702 3.462-2.45 5.393-2.171a5.17 5.17 0 0 1 3.248 1.79C21.501 5.872 22 7.27 22 8.972c0 3.474-2.56 6.49-4.835 8.516a29.628 29.628 0 0 1-4.678 3.386 1 1 0 0 1-.974 0c-.14-.08-.279-.162-.417-.245a29.633 29.633 0 0 1-4.261-3.14C4.56 15.461 2 12.445 2 8.971c0-1.703.499-3.1 1.359-4.125a5.17 5.17 0 0 1 3.248-1.79Z"></path>
                            </svg></span></span></div>
            </div>
            <div class="mt-CardAd-footer">
                <div class="mt-CardAd-footerFinancingInfoContainer">* Permanencia: 12 meses · Kilómetros incluidos: 10.000 /año</div>
            </div>
        </div>
    </div>
    <div data-ad-id="58172147">
        <div class="mt-AnimationFadeOut mt-ListAds-item mt-CardAd mt-CardBasic">
            <div class="sui-AtomCard sui-AtomCard--responsive" role="button">
                <div class="sui-AtomCard-media">
                    <div class="mt-CardAd-mediaContainer"><a class="mt-CardAd-media " href="/renting/fiat/tipo/13_easy_70kw_95cv_diesel_mjet_5p-diesel-2018-58172147-vsre" target="_self" title="FIAT Tipo 1.3 Easy 70kW 95CV diesel Mjet. 5p 5p.">
                            <div class="sui-AtomImage is-loaded">
                                <figure class="sui-AtomImage-figure">
                                    <picture><img alt="FIAT Tipo 1.3 Easy 70kW 95CV diesel Mjet. 5p 5p." class="mt-CardAd-mediaImage" decoding="auto" fetchpriority="auto" loading="eager" height="189" src="https://a.ccdn.es/cnet/2024/06/28/58172147/1930024420_g.jpg/252x189cut/" width="252" title="FIAT Tipo 1.3 Easy 70kW 95CV diesel Mjet. 5p 5p."></picture>
                                </figure>
                            </div>
                        </a></div>
                </div>
                <div class="sui-AtomCard-info"><a href="/renting/fiat/tipo/13_easy_70kw_95cv_diesel_mjet_5p-diesel-2018-58172147-vsre" class="mt-CardBasic-titleLink" title="FIAT Tipo 1.3 Easy 70kW 95CV diesel Mjet. 5p 5p." target="_self">
                        <div class="mt-CardAdPrice">
                            <div class="mt-CardAdPrice-subscription mt-CardAdPrice-subscription--fullwidth"><span class="mt-CardAdPrice-subscriptionLabel">Cuota desde</span>
                                <div class="mt-CardAdPrice-subscriptionAmount">
                                    <div class="mt-TitleBasic-titleWrapper mt-TitleBasic-titleWrapper--currentColor mt-TitleBasic-titleWrapper--left">
                                        <h3 class="mt-TitleBasic-title mt-TitleBasic-title--s mt-TitleBasic-title--currentColor">300&nbsp;€</h3>
                                    </div><span class="mt-CardAdPrice-subscriptionAmountPerMonth">/mes*</span>
                                </div>
                                <div class="mt-CardAdPrice-subscriptionLabel"><span class="mt-CardAdPrice-subscriptionLabel--highlight">IVA incluido</span></div>
                            </div>
                        </div>
                        <h2 class="mt-CardBasic-title mt-CardAd-title--oneLine" data-testid="card-ad-title">FIAT Tipo 1.3 Easy 70kW 95CV diesel Mjet. 5p 5p.</h2>
                        <ul class="mt-CardAd-attr">
                            <li class="mt-CardAd-attrItem">Diesel</li>
                            <li class="mt-CardAd-attrItem">2019</li>
                            <li class="mt-CardAd-attrItem">Manual</li>
                        </ul>
                        <ul class="mt-CardAd-tags">
                            <div class="sui-AtomBadge sui-AtomBadge-size-medium sui-AtomBadge-type-gray sui-AtomBadge-design-soft"><span class="sui-AtomBadge-icon-text" title="Segunda mano">Segunda mano</span></div>
                        </ul>
                    </a></div>
            </div>
            <div class="mt-CardAd-fav">
                <div class="mt-CardAd-favIcon"><span class="sui-AtomIcon sui-AtomIcon--medium sui-AtomIcon--currentColor"><span><svg viewBox="0 0 24 24" xmlns="http://www.w3.org/2000/svg">
                                <path d="M6.607 3.057c1.93-.279 4.02.469 5.393 2.171 1.373-1.702 3.462-2.45 5.393-2.171a5.17 5.17 0 0 1 3.248 1.79C21.501 5.872 22 7.27 22 8.972c0 3.474-2.56 6.49-4.835 8.516a29.628 29.628 0 0 1-4.678 3.386 1 1 0 0 1-.974 0c-.14-.08-.279-.162-.417-.245a29.633 29.633 0 0 1-4.261-3.14C4.56 15.461 2 12.445 2 8.971c0-1.703.499-3.1 1.359-4.125a5.17 5.17 0 0 1 3.248-1.79Z"></path>
                            </svg></span></span></div>
            </div>
            <div class="mt-CardAd-footer">
                <div class="mt-CardAd-footerFinancingInfoContainer">* Permanencia: 12 meses · Kilómetros incluidos: 10.000 /año</div>
            </div>
        </div>
    </div>
</div>
'''

# Parsear el HTML con BeautifulSoup
soup = BeautifulSoup(html, 'html.parser')

# Encontrar todos los contenedores de vehículos (cada uno debería estar encapsulado en un contenedor div, por ejemplo)
vehicle_containers = soup.find_all('div', class_='mt-ListAds-item')

# Iterar sobre cada vehículo
for vehicle_container in vehicle_containers:
    # Extraer el título del vehículo
    title_element = vehicle_container.find('h2', class_='mt-CardBasic-title')
    vehicle_title = title_element.text.strip() if title_element else "No encontrado"

    # Extraer atributos (combustible, año, transmisión)
    attr_elements = vehicle_container.find_all('li', class_='mt-CardAd-attrItem')
    attributes = [attr.text.strip() for attr in attr_elements]

    # Extraer si es nuevo
    new_element = vehicle_container.find('span', class_='sui-AtomBadge-icon-text', title='Nuevo')
    is_new = "Sí" if new_element else "No"

    # Extraer el precio mensual
    price_element = vehicle_container.find('h3', class_='mt-TitleBasic-title')
    monthly_price = price_element.text.strip() if price_element else "No encontrado"

    # Imprimir los resultados de cada vehículo
    print("Título del vehículo:", vehicle_title)
    print("Atributos:", attributes)
    print("Nuevo:", is_new)
    print("Precio mensual:", monthly_price)
    print("-" * 50)  # Separador entre vehículos
# Out:
# Título del vehículo: SEAT Ibiza 1.0 TSI 70kW 95CV Reference XL 5p.
# Atributos: ['Gasolina', '2023', 'Manual']
# Nuevo: Sí
# Precio mensual: 253 €
# --------------------------------------------------
# Título del vehículo: RENAULT Clio Business SCe 49 kW 67CV 5p.
# Atributos: ['Gasolina', '2021', 'Manual']
# Nuevo: No
# Precio mensual: 295 €
# --------------------------------------------------
# Título del vehículo: RENAULT Clio Business SCe 49 kW 67CV 5p.
# Atributos: ['Gasolina', '2021', 'Manual']
# Nuevo: No
# Precio mensual: 295 €
# --------------------------------------------------
# Título del vehículo: PEUGEOT 208 Active Puretech 100 5p.
# Atributos: ['Gasolina', '2023', 'Manual']
# Nuevo: Sí
# Precio mensual: 321 €
# --------------------------------------------------
# Título del vehículo: BMW Serie 1 116d 5p.
# Atributos: ['Diesel', '2023', 'Manual']
# Nuevo: Sí
# Precio mensual: 399 €
# --------------------------------------------------
# ...
